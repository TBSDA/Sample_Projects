# %% [markdown]
# # Stroke Prediction Model Searching v2

# %% [markdown]
# Let's do some research to create stroke prediction model based on the healthcare-dataset-stroke-data dataset.<br>
# <br>
# Source: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset<br>

# %% [markdown]
# #### Acknowledgements
# (Confidential Source) - Use only for educational purposes
# If you use this dataset in your research, please credit the author.

# %% [markdown]
# It is a second searching notebook. The first one did not provide satisfactory results.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import LabelBinarizer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import FeatureUnion
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Let's get together the pipelines from Stroke_Prediction_Cleansing_and_Preprocessing notebook.

# %%
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names]

class MyLabelBinarizer(LabelBinarizer):
    def fit_transform(self, X, y=None):
        return super(LabelBinarizer, self).fit_transform(X)

class CustomLimitedImputer(BaseEstimator, TransformerMixin):
    ''' Simple customized imputer to change the following:
        smoking_status to "never smoked" if age < 10 and smoking_status = "Unknown"
        work_type to "children" if age < 17 and swork_type = "Never_worked" '''
    def __init__(self, attribute_names):
        assert all(attr in ['smoking_status', 'work_type'] for attr in attribute_names), 'Only smoking_status and work_type are supported'
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X = X.copy()
        for attr in self.attribute_names:
            if attr == 'smoking_status':
                X.loc[(X.age < 10) & (X.smoking_status == 'Unknown'), 'smoking_status'] = 'never smoked'
            elif attr == 'work_type':
                X.loc[(X.age < 17) & (X.work_type == 'Never_worked'), 'work_type'] = 'children'
        X.drop(['age'], axis=1, inplace=True)
        return X.values

# pipelines
cat_yn_pipeline = Pipeline([
        ("select_bin", DataFrameSelector(['ever_married'])),
        ("bin_encoder", MyLabelBinarizer()),
    ])

cat_oh_pipeline = Pipeline([
        ("select_cat", DataFrameSelector(['smoking_status', 'work_type', 'age'])), # age is used as a parameter
        ("imputer", CustomLimitedImputer(['smoking_status', 'work_type'])),
        ("cat_encoder", OneHotEncoder(sparse=False)),
    ])

num_pipeline = Pipeline([
        ("select_numeric", DataFrameSelector(['age', 'avg_glucose_level'])),
        ("scale", StandardScaler()),
    ])

# final preprocessing pipeline
preprocess_pipeline = FeatureUnion(transformer_list=[
        ('cat_yn_pipeline', cat_yn_pipeline),
        ('cat_oh_pipeline', cat_oh_pipeline),
        ('num_pipeline', num_pipeline),
    ])

# %%
data = pd.read_csv('Data/healthcare-dataset-stroke-data.csv', index_col='id')

# %%
data
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
# ...       ...   ...           ...            ...          ...            ...
# 18234  Female  80.0             1              0          Yes        Private
# 44873  Female  81.0             0              0          Yes  Self-employed
# 19723  Female  35.0             0              0          Yes  Self-employed
# 37544    Male  51.0             0              0          Yes        Private
# 44679  Female  44.0             0              0          Yes       Govt_job
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# id
# 9046           Urban             228.69  36.6  formerly smoked       1
# 51676          Rural             202.21   NaN     never smoked       1
# 31112          Rural             105.92  32.5     never smoked       1
# 60182          Urban             171.23  34.4           smokes       1
# 1665           Rural             174.12  24.0     never smoked       1
# ...              ...                ...   ...              ...     ...
# 18234          Urban              83.75   NaN     never smoked       0
# 44873          Urban             125.20  40.0     never smoked       0
# 19723          Rural              82.99  30.6     never smoked       0
# 37544          Rural             166.29  25.6  formerly smoked       0
# 44679          Urban              85.28  26.2          Unknown       0
#
# [5110 rows x 11 columns]

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(data[data.columns[:-1]], data.stroke, test_size=0.2, random_state=24, stratify=data.stroke)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=24, stratify=y_train_val)

# %%
X_train = preprocess_pipeline.fit_transform(X_train)
X_val = preprocess_pipeline.transform(X_val)
X_test = preprocess_pipeline.transform(X_test)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
print(y_train.value_counts())
print(y_val.value_counts())
# Out:
# (3270, 12)
# (818, 12)
# (1022, 12)
# (3270,)
# (818,)
# (1022,)
# 0    3111
# 1     159
# Name: stroke, dtype: int64
# 0    778
# 1     40
# Name: stroke, dtype: int64

# %% [markdown]
# The train set will be used for training the models, the val set to validate the models and the test set will be locked until the final model and hyperparameters will be chosen.

# %% [markdown]
# Firstly, the metric needs to be selected.<br>
# The choice is F2 score because is better for the models where positive class and preventing false negatives are more important.<br>
# Alternatively, the PR AUC can be considered.<br>

# %%
from sklearn.metrics import fbeta_score, make_scorer

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %% [markdown]
# Let's start with a couple basic models.

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lreg = LogisticRegression(random_state=24)

lreg_scores = cross_val_score(lreg, X_train, y_train, cv=10, scoring=f2_scorer)
lreg_scores.mean()
# Out:
# 0.0

# %% [markdown]
# Nice, good start.

# %% [markdown]
# Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()

lda_scores = cross_val_score(lda, X_train, y_train, cv=10, scoring=f2_scorer)
lda_scores.mean()
# Out:
# 0.051719022855985106

# %% [markdown]
# Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

gnb_scores = cross_val_score(gnb, X_train, y_train, cv=10, scoring=f2_scorer)
gnb_scores.mean()
# Out:
# 0.2633839674974345

# %% [markdown]
# K-Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh = KNeighborsClassifier()

neigh_scores = cross_val_score(neigh, X_train, y_train, cv=10, scoring=f2_scorer)
neigh_scores.mean()
# Out:
# 0.06736892424757447

# %% [markdown]
# Support Vector Machines

# %%
from sklearn.svm import SVC

# %%
# C-Support Vector Classification
svc = SVC()

svc_scores = cross_val_score(svc, X_train, y_train, cv=10, scoring=f2_scorer)
svc_scores.mean()
# Out:
# 0.0

# %%
from sklearn.svm import LinearSVC

# %%
#Linear Support Vector Classification
lsvc = LinearSVC()

lsvc_scores = cross_val_score(lsvc, X_train, y_train, cv=10, scoring=f2_scorer)
lsvc_scores.mean()
# Out:
# 0.0

# %%
from sklearn.linear_model import SGDClassifier

# %%
# SVM with stochastic gradient descent (SGD)
sgdc = SGDClassifier(random_state=24)

sgdc_scores = cross_val_score(sgdc, X_train, y_train, cv=10, scoring=f2_scorer)
sgdc_scores.mean()
# Out:
# 0.0

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(random_state=24)

dtc_scores = cross_val_score(dtc, X_train, y_train, cv=10, scoring=f2_scorer)
dtc_scores.mean()
# Out:
# 0.14150210093329052

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(random_state=24)

rfc_scores = cross_val_score(rfc, X_train, y_train, cv=10, scoring=f2_scorer)
rfc_scores.mean()
# Out:
# 0.04307001428863033

# %%
Extra Trees Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
etc = ExtraTreesClassifier(random_state=24)

etc_scores = cross_val_score(etc, X_train, y_train, cv=10, scoring=f2_scorer)
etc_scores.mean()
# Out:
# 0.06170446876071828

# %% [markdown]
# Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bc = BaggingClassifier(random_state=24)

bc_scores = cross_val_score(bc, X_train, y_train, cv=10, scoring=f2_scorer)
bc_scores.mean()
# Out:
# 0.0636905976924348

# %% [markdown]
# Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(random_state=24)

gbc_scores = cross_val_score(gbc, X_train, y_train, cv=10, scoring=f2_scorer)
gbc_scores.mean()
# Out:
# 0.01551226551226551

# %% [markdown]
# AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
abc = AdaBoostClassifier(random_state=24)

abc_scores = cross_val_score(abc, X_train, y_train, cv=10, scoring=f2_scorer)
abc_scores.mean()
# Out:
# 0.008064516129032256

# %% [markdown]
# Hist Gradient Boosting Classifier

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
# from sklearn.experimental import enable_hist_gradient_boosting

# %%
hgbc = HistGradientBoostingClassifier(random_state=24)

hgbc_scores = cross_val_score(hgbc, X_train, y_train, cv=10, scoring=f2_scorer)
hgbc_scores.mean()
# Out:
# 0.06430613376193506

# %% [markdown]
# Let's look into some outlier detection and anomaly detection algorithms.

# %% [markdown]
# The new datasets are required to evaluate the model.

# %%
X_train_out, X_test_out, y_train_out, y_test_out = train_test_split(X_train, y_train, test_size=0.5, random_state=24, stratify=y_train)

# %%
One-Class SVM

# %%
from sklearn.svm import OneClassSVM

# %%
oc_svm = OneClassSVM()

X_train_out = X_train_out[y_train_out==0]
oc_svm.fit(X_train_out)

y_pred = oc_svm.predict(X_test_out)

# the predict output is -1 and 1 instead of 1 and 0, respectively
y_test_out[y_test_out == 1] = -1
y_test_out[y_test_out == 0] = 1

f2_score = fbeta_score(y_test_out, y_pred, pos_label=-1, beta=2)
f2_score
# Out:
# 0.3093220338983051

# %% [markdown]
# Isolation Forest

# %%
from sklearn.ensemble import IsolationForest

# %%
ilf = IsolationForest(random_state=24)
ilf.fit(X_train_out)

y_pred = ilf.predict(X_test_out)


f2_score = fbeta_score(y_test_out, y_pred, pos_label=-1, beta=2)
f2_score
# Out:
# 0.27702089009990916

# %% [markdown]
# Local Outlier Factor

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
lof = LocalOutlierFactor(n_neighbors=5, novelty=True)
lof.fit(X_train_out)

y_pred = lof.predict(X_test_out)


f2_score = fbeta_score(y_test_out, y_pred, pos_label=-1, beta=2)
f2_score
# Out:
# 0.11930585683297178

# %% [markdown]
# First run with default hiperparameters is done. Let's check the results:<br>
# Result  Classification Algorithm<br>
# __________________________________
# 0.0&emsp;&emsp;LogisticRegression<br>
# 0.0517&emsp;LinearDiscriminantAnalysis<br>
# 0.2634&emsp;GaussianNB<br>
# 0.0674&emsp;KNeighborsClassifier<br>
# 0.0&emsp;&emsp;SVC<br>
# 0.0&emsp;&emsp;LinearSVC<br>
# 0.0&emsp;&emsp;SGDClassifier<br>
# 0.1415&emsp;DecisionTreeClassifier<br>
# 0.0431&emsp;RandomForestClassifier<br>
# 0.0617&emsp;ExtraTreesClassifier<br>
# 0.0637&emsp;BaggingClassifier<br>
# 0.0155&emsp;GradientBoostingClassifier<br>
# 0.0081&emsp;AdaBoostClassifier<br>
# 0.0643&emsp;HistGradientBoostingClassifier<br>
# <br>
# Result  Outlier Detection/Anomaly Detection Algorithm<br>
# _____________________________________________________
# 0.3093&emsp;OneClassSVM<br>
# 0.2770&emsp;IsolationForest<br>
# 0.1193&emsp;LocalOutlierFactor<br>
# <br>
# Looks like the outlier/anomaly detection algorithms perform better. Anyway, before jumping to the conclusion let's check the classification algorithms with some data resampling. <br>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
models = [
    LogisticRegression(random_state=24),
    LinearDiscriminantAnalysis(),
    GaussianNB(),
    KNeighborsClassifier(),
    SVC(),
    LinearSVC(),
    SGDClassifier(random_state=24),
    DecisionTreeClassifier(random_state=24),
    RandomForestClassifier(random_state=24),
    ExtraTreesClassifier(random_state=24),
    BaggingClassifier(random_state=24),
    GradientBoostingClassifier(random_state=24),
    AdaBoostClassifier(random_state=24),
    HistGradientBoostingClassifier(random_state=24)
]

# %%
def get_models_scores(models_in, X, y, cv):
    ''' Get scores for models based on cross_val_score.
        Parameters:
            models_in - models to evaluate
            X         - X train dataset
            y         - y train dataset
            cv        - cross-validation splitting strategy
        Result:
            Dataframe with the coss_val_score results'''
    results = pd.DataFrame(columns=['Model', cv])
    for model in models_in:
        results.loc[len(results)] = [str(model).split('(')[0], round(cross_val_scores(model, X, y, cv), 4)]
    results.index += 1
    return results

# %%
def cross_val_scores(model, X, y, cv):
    ''' Calculate the cross validation scores based on f2_scores metric and then the mean of them.
        Parameters:
            model    - model to be used for fitting data and predictions
            X        - X train dataset
            y        - y train dataset
            cv       - Cross validation splitting strategy
        Returns:
            The mean value of calculated f2 scores. '''
    scores = cross_val_score(model, X, y, cv=cv, scoring=f2_scorer)
    return scores.mean()

# %% [markdown]
# Before resampling let's check if RepeatedStratifiedKFold has any impact on the results.

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
splitter = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %%
scores = get_models_scores(models, X_train, y_train, cv=splitter)

# %%
scores
# Out:
#                              Model  \
# 1               LogisticRegression
# 2       LinearDiscriminantAnalysis
# 3                       GaussianNB
# 4             KNeighborsClassifier
# 5                              SVC
# 6                        LinearSVC
# 7                    SGDClassifier
# 8           DecisionTreeClassifier
# 9           RandomForestClassifier
# 10            ExtraTreesClassifier
# 11               BaggingClassifier
# 12      GradientBoostingClassifier
# 13              AdaBoostClassifier
# 14  HistGradientBoostingClassifier
#
#     RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1)
# 1                                              0.0000
# 2                                              0.0402
# 3                                              0.2632
# 4                                              0.0717
# 5                                              0.0000
# 6                                              0.0000
# 7                                              0.0000
# 8                                              0.1564
# 9                                              0.0677
# 10                                             0.0646
# 11                                             0.0512
# 12                                             0.0253
# 13                                             0.0025
# 14                                             0.0627

# %% [markdown]
# Seems they are slightly better, generally speaking.

# %% [markdown]
# Resampling

# %% [markdown]
# Random Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(sampling_strategy=0.1, random_state=24)
X_ros, y_ros = ros.fit_resample(X_train, y_train)

# %%
'X', X_ros.shape, X_train.shape, 'y', y_ros.shape, y_train.shape
# Out:
# ('X', (3422, 12), (3270, 12), 'y', (3422,), (3270,))

# %%
y_ros.value_counts(), y_train.value_counts()
# Out:
# (0    3111
#  1     311
#  Name: stroke, dtype: int64,
#  0    3111
#  1     159
#  Name: stroke, dtype: int64)

# %%
ros_scores = get_models_scores(models, X_ros, y_ros, cv=splitter)
ros_scores
# Out:
#                              Model  \
# 1               LogisticRegression
# 2       LinearDiscriminantAnalysis
# 3                       GaussianNB
# 4             KNeighborsClassifier
# 5                              SVC
# 6                        LinearSVC
# 7                    SGDClassifier
# 8           DecisionTreeClassifier
# 9           RandomForestClassifier
# 10            ExtraTreesClassifier
# 11               BaggingClassifier
# 12      GradientBoostingClassifier
# 13              AdaBoostClassifier
# 14  HistGradientBoostingClassifier
#
#     RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1)
# 1                                              0.0582
# 2                                              0.1631
# 3                                              0.4076
# 4                                              0.3514
# 5                                              0.0000
# 6                                              0.0000
# 7                                              0.0000
# 8                                              0.7731
# 9                                              0.7966
# 10                                             0.7896
# 11                                             0.7443
# 12                                             0.2581
# 13                                             0.1234
# 14                                             0.6263

# %%
scores.values[:, 1].mean()
# Out:
# 0.05753571428571428

# %%
ros_scores.values[:, 1].mean()
# Out:
# 0.3636928571428571

# %% [raw]
# Looks better. Let's run it a couple times with higher sampling value.

# %%
sample_vs = [0.2, 0.4, 0.6, 0.8, 1]
for sample_v in sample_vs:
    ros = RandomOverSampler(sampling_strategy=sample_v, random_state=24)
    print('==========================')
    print('Sampling strategy = ', sample_v)
    X_ros, y_ros = ros.fit_resample(X_train, y_train)
    ros_scores = get_models_scores(models, X_ros, y_ros, cv=splitter)
    display(ros_scores)
    print('Mean', ros_scores.values[:, 1].mean())
# Out:
# ==========================
# Sampling strategy =  0.2
#                              Model  \
# 1               LogisticRegression
# 2       LinearDiscriminantAnalysis
# 3                       GaussianNB
# 4             KNeighborsClassifier
# 5                              SVC
# 6                        LinearSVC
# 7                    SGDClassifier
# 8           DecisionTreeClassifier
# 9           RandomForestClassifier
# 10            ExtraTreesClassifier
# 11               BaggingClassifier
# 12      GradientBoostingClassifier
# 13              AdaBoostClassifier
# 14  HistGradientBoostingClassifier
#
#     RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1)
# 1                                              0.2915
# 2                                              0.3719
# 3                                              0.5704
# 4                                              0.7569
# 5                                              0.2851
# 6                                              0.2492
# 7                                              0.2074
# 8                                              0.9414
# 9                                              0.9549
# 10                                             0.9609
# 11                                             0.9447
# 12                                             0.5465
# 13                                             0.3606
# 14                                             0.8711
# Mean 0.59375
# ==========================
# Sampling strategy =  0.4
#                              Model  \
# 1               LogisticRegression
# 2       LinearDiscriminantAnalysis
# 3                       GaussianNB
# 4             KNeighborsClassifier
# 5                              SVC
# 6                        LinearSVC
# 7                    SGDClassifier
# 8           DecisionTreeClassifier
# 9           RandomForestClassifier
# 10            ExtraTreesClassifier
# 11               BaggingClassifier
# 12      GradientBoostingClassifier
# 13              AdaBoostClassifier
# 14  HistGradientBoostingClassifier
#
#     RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1)
# 1                                              0.6168
# 2                                              0.6506
# 3                                              0.7190
# 4                                              0.9340
# 5                                              0.6761
# 6                                              0.6208
# 7                                              0.6095
# 8                                              0.9751
# 9                                              0.9824
# 10                                             0.9875
# 11                                             0.9802
# 12                                             0.7584
# 13                                             0.6407
# 14                                             0.9581
# Mean 0.7935142857142857
# ==========================
# Sampling strategy =  0.6
#                              Model  \
# 1               LogisticRegression
# 2       LinearDiscriminantAnalysis
# 3                       GaussianNB
# 4             KNeighborsClassifier
# 5                              SVC
# 6                        LinearSVC
# 7                    SGDClassifier
# 8           DecisionTreeClassifier
# 9           RandomForestClassifier
# 10            ExtraTreesClassifier
# 11               BaggingClassifier
# 12      GradientBoostingClassifier
# 13              AdaBoostClassifier
# 14  HistGradientBoostingClassifier
#
#     RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1)
# 1                                              0.7105
# 2                                              0.7246
# 3                                              0.7908
# 4                                              0.9622
# 5                                              0.7698
# 6                                              0.7194
# 7                                              0.7166
# 8                                              0.9848
# 9                                              0.9886
# 10                                             0.9920
# 11                                             0.9872
# 12                                             0.8510
# 13                                             0.7406
# 14                                             0.9767
# Mean 0.851057142857143
# ==========================
# Sampling strategy =  0.8
#                              Model  \
# 1               LogisticRegression
# 2       LinearDiscriminantAnalysis
# 3                       GaussianNB
# 4             KNeighborsClassifier
# 5                              SVC
# 6                        LinearSVC
# 7                    SGDClassifier
# 8           DecisionTreeClassifier
# 9           RandomForestClassifier
# 10            ExtraTreesClassifier
# 11               BaggingClassifier
# 12      GradientBoostingClassifier
# 13              AdaBoostClassifier
# 14  HistGradientBoostingClassifier
#
#     RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1)
# 1                                              0.7599
# 2                                              0.7599
# 3                                              0.8337
# 4                                              0.9712
# 5                                              0.8036
# 6                                              0.7630
# 7                                              0.7517
# 8                                              0.9888
# 9                                              0.9911
# 10                                             0.9937
# 11                                             0.9909
# 12                                             0.8943
# 13                                             0.8162
# 14                                             0.9792
# Mean 0.8783714285714287
# ==========================
# Sampling strategy =  1
#                              Model  \
# 1               LogisticRegression
# 2       LinearDiscriminantAnalysis
# 3                       GaussianNB
# 4             KNeighborsClassifier
# 5                              SVC
# 6                        LinearSVC
# 7                    SGDClassifier
# 8           DecisionTreeClassifier
# 9           RandomForestClassifier
# 10            ExtraTreesClassifier
# 11               BaggingClassifier
# 12      GradientBoostingClassifier
# 13              AdaBoostClassifier
# 14  HistGradientBoostingClassifier
#
#     RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1)
# 1                                              0.8009
# 2                                              0.8045
# 3                                              0.8580
# 4                                              0.9768
# 5                                              0.8363
# 6                                              0.8010
# 7                                              0.7950
# 8                                              0.9914
# 9                                              0.9934
# 10                                             0.9950
# 11                                             0.9928
# 12                                             0.9158
# 13                                             0.8569
# 14                                             0.9817
# Mean 0.8999642857142857

# %% [raw]
# Let's run it again with the validation results.

# %%
def get_models_scores_vs_val_for_sampling(models_in, X, y, cv, X_v, y_v, sample_value):
    ''' Get scores for models based on cross_val_score on train dataset 
        and prediction scores for valudation dataset.
        Parameters:
            models_in    - models to evaluate
            X            - X train dataset
            y            - y train dataset
            cv           - cross-validation splitting strategy
            X_v          - X validation dataset
            y_v          - y validation dataset
            sample_value - used only for Dataframe columns name
        Result:
            Dataframe with the coss_val_score and validation results'''
    results = pd.DataFrame()
    results['Models'] = [str(model).split('(')[0] for model in models_in]
    results.set_index('Models', inplace=True)
    for model in models_in:
        results.loc[str(model).split('(')[0], [f'ss={sample_value} train']] = round(cross_val_scores(model, X, y, cv), 4)
        results.loc[str(model).split('(')[0], [f'ss={sample_value} val']] = round(get_val_pred_score(model, X, y, X_v, y_v), 4)
    return results

# %%
def get_val_pred_score(model, X, y, X_v, y_v):
    ''' Calculate the f2_score of prediction for given model. 
        Parameters:
            model    - model to be used for fitting data and predictions
            X        - X train dataset
            y        - y train dataset
            X_v      - X validation dataset (will work for test dataset as well)
            y_v      - y validation dataset (will work for test dataset as well)
        Result:
            f2_score of predicted values. '''
    model.fit(X, y)
    y_pred = model.predict(X_v)
    return fbeta_score(y_v, y_pred, beta=2)

# %%
sample_vs = [x/10 for x in range(1, 10, 2)]+[1]
ros_results = pd.DataFrame()
for sample_v in sample_vs:
    ros = RandomOverSampler(sampling_strategy=sample_v, random_state=24)
#     print('==========================')
#     print('Sampling strategy = ', sample_v)
    X_ros, y_ros = ros.fit_resample(X_train, y_train)
    ros_scores = get_models_scores_vs_val_for_sampling(models, X_ros, y_ros, splitter, X_val, y_val, sample_v)
    ros_results = pd.concat([ros_results, ros_scores], axis=1)
ros_results
# Out:
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0582      0.0000        0.5009
# LinearDiscriminantAnalysis            0.1631      0.0565        0.5424
# GaussianNB                            0.4076      0.2710        0.6634
# KNeighborsClassifier                  0.3514      0.1768        0.8874
# SVC                                   0.0000      0.0000        0.5606
# LinearSVC                             0.0000      0.0000        0.4734
# SGDClassifier                         0.0000      0.0000        0.4311
# DecisionTreeClassifier                0.7731      0.1733        0.9692
# RandomForestClassifier                0.7966      0.0843        0.9768
# ExtraTreesClassifier                  0.7896      0.1124        0.9833
# BaggingClassifier                     0.7443      0.0562        0.9722
# GradientBoostingClassifier            0.2581      0.0000        0.6596
# AdaBoostClassifier                    0.1234      0.0000        0.5804
# HistGradientBoostingClassifier        0.6263      0.0857        0.9384
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.3802        0.6704      0.3963
# LinearDiscriminantAnalysis          0.3788        0.6835      0.4154
# GaussianNB                          0.2621        0.7594      0.2567
# KNeighborsClassifier                0.2281        0.9524      0.2281
# SVC                                 0.2917        0.7408      0.3583
# LinearSVC                           0.3770        0.6776      0.3892
# SGDClassifier                       0.4315        0.6406      0.4108
# DecisionTreeClassifier              0.1302        0.9809      0.1202
# RandomForestClassifier              0.1064        0.9864      0.0785
# ExtraTreesClassifier                0.1143        0.9903      0.0852
# BaggingClassifier                   0.0798        0.9846      0.0269
# GradientBoostingClassifier          0.2532        0.8167      0.3069
# AdaBoostClassifier                  0.2326        0.6826      0.3302
# HistGradientBoostingClassifier      0.1493        0.9707      0.1549
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.7443      0.4365        0.7863
# LinearDiscriminantAnalysis            0.7476      0.4319        0.7848
# GaussianNB                            0.8157      0.2564        0.8467
# KNeighborsClassifier                  0.9677      0.2281        0.9743
# SVC                                   0.7903      0.3239        0.8266
# LinearSVC                             0.7456      0.4331        0.7865
# SGDClassifier                         0.7377      0.4373        0.7806
# DecisionTreeClassifier                0.9863      0.1036        0.9896
# RandomForestClassifier                0.9901      0.0798        0.9923
# ExtraTreesClassifier                  0.9933      0.0872        0.9949
# BaggingClassifier                     0.9895      0.1081        0.9917
# GradientBoostingClassifier            0.8779      0.3538        0.9052
# AdaBoostClassifier                    0.7847      0.3209        0.8468
# HistGradientBoostingClassifier        0.9775      0.1724        0.9807
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.4084      0.8009    0.4096
# LinearDiscriminantAnalysis          0.4237      0.8045    0.4118
# GaussianNB                          0.2538      0.8580    0.2528
# KNeighborsClassifier                0.2281      0.9768    0.2281
# SVC                                 0.3476      0.8363    0.3759
# LinearSVC                           0.4177      0.8010    0.4127
# SGDClassifier                       0.3795      0.7950    0.4146
# DecisionTreeClassifier              0.0781      0.9914    0.0777
# RandomForestClassifier              0.1036      0.9934    0.1042
# ExtraTreesClassifier                0.0857      0.9950    0.0862
# BaggingClassifier                   0.0811      0.9928    0.1075
# GradientBoostingClassifier          0.3768      0.9158    0.3672
# AdaBoostClassifier                  0.3109      0.8569    0.3448
# HistGradientBoostingClassifier      0.2292      0.9817    0.2600

# %% [markdown]
# Let's run it for more oversampling and undersampling techniques.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SVMSMOTE
from imblearn.over_sampling import SMOTENC
from imblearn.over_sampling import ADASYN

from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import CondensedNearestNeighbour
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.under_sampling import NeighbourhoodCleaningRule

# %%
# resampling techniques which use the sampling_strategy
resampling_tqs_ss = [
    SMOTE,
    BorderlineSMOTE,
    SVMSMOTE,
    SMOTENC,
    ADASYN,
    RandomUnderSampler,
]

# resampling techniques which not use the sampling_strategy
resampling_tqs_no_ss = [
    CondensedNearestNeighbour,
    TomekLinks, # no random
    EditedNearestNeighbours, # no random
    NeighbourhoodCleaningRule # no random
]

# techniques without random state
tqs_wo_random_state = [TomekLinks, EditedNearestNeighbours, NeighbourhoodCleaningRule]

# %%
def get_train_val_results_for_sampling(sampling_tq, tqs_wo_rs, sample_vs, models, X, y, splitter, X_val, y_val, ss=True):
    ''' Get scores for models based on cross_val_score on train dataset 
        and prediction scores for valudation dataset
        based on resampling technique and sampling strategies.
    Parameters:
        sampling_tq  - sampling technique
        tqs_wo_rs    - list of techniques which not use a random_state
        sample_vs    - list of ratios to be used for methods with sampling_strategy
        models       - models to evaluate
        X            - X train dataset
        y            - y train dataset
        splitter     - cross-validation splitting strategy
        X_val        - X validation dataset
        y_val        - y validation dataset
        ss           - indicate whether the models use sampling_strategy or not
    Result:
        Dataframe with the coss_val_score and validation results for given models and sampling technique. '''
    
    stq_results = pd.DataFrame()
    if ss:
        for sample_v in sample_vs:
            if sampling_tq == SMOTENC:
                stq = sampling_tq(sampling_strategy=sample_v, categorical_features=[x for x in range(10)], random_state=24)
            elif sampling_tq in tqs_wo_rs:
                stq = sampling_tq(sampling_strategy=sample_v)
            else:
                stq = sampling_tq(sampling_strategy=sample_v, random_state=24)
            X_stq, y_stq = stq.fit_resample(X, y)
            stq_scores = get_models_scores_vs_val_for_sampling(models, X_stq, y_stq, splitter, X_val, y_val, sample_v)
            stq_results = pd.concat([stq_results, stq_scores], axis=1)
    else:
        if sampling_tq in tqs_wo_rs:
            stq = sampling_tq()
        else:
            stq = sampling_tq(random_state=24)
        X_stq, y_stq = stq.fit_resample(X, y)
        stq_results = get_models_scores_vs_val_for_sampling(models, X_stq, y_stq, splitter, X_val, y_val, sample_v)
    return stq_results

# %%
sample_vs = [x/10 for x in range(1, 10, 2)]+[1]
for resampling_tq in resampling_tqs_ss:
    resampling_tq_str = str(resampling_tq).split('.')[-1][:-2]
    print(f'Train vs validation results for {resampling_tq_str} technique.')
    display(get_train_val_results_for_sampling(resampling_tq, 
                                               tqs_wo_random_state, 
                                               sample_vs, 
                                               models, 
                                               X_train, y_train, 
                                               splitter, 
                                               X_val, y_val))
    print()
# Out:
# Train vs validation results for SMOTE technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0959      0.0000        0.5437
# LinearDiscriminantAnalysis            0.2396      0.0838        0.5802
# GaussianNB                            0.4154      0.2759        0.6813
# KNeighborsClassifier                  0.3469      0.1823        0.7436
# SVC                                   0.0013      0.0000        0.6032
# LinearSVC                             0.0000      0.0000        0.5438
# SGDClassifier                         0.0226      0.0000        0.4806
# DecisionTreeClassifier                0.4386      0.2500        0.7094
# RandomForestClassifier                0.3916      0.0829        0.7652
# ExtraTreesClassifier                  0.4846      0.0789        0.7731
# BaggingClassifier                     0.3299      0.0833        0.7130
# GradientBoostingClassifier            0.2491      0.0000        0.6351
# AdaBoostClassifier                    0.1525      0.0000        0.5848
# HistGradientBoostingClassifier        0.3687      0.1087        0.7320
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.3745        0.6909      0.4066
# LinearDiscriminantAnalysis          0.3506        0.7039      0.4303
# GaussianNB                          0.2778        0.7770      0.2774
# KNeighborsClassifier                0.2222        0.8657      0.2226
# SVC                                 0.3000        0.7468      0.3642
# LinearSVC                           0.3654        0.6979      0.4054
# SGDClassifier                       0.3052        0.6860      0.4084
# DecisionTreeClassifier              0.2058        0.8168      0.1953
# RandomForestClassifier              0.1802        0.8657      0.1452
# ExtraTreesClassifier                0.1556        0.8703      0.1282
# BaggingClassifier                   0.1214        0.8421      0.1549
# GradientBoostingClassifier          0.1478        0.7763      0.2041
# AdaBoostClassifier                  0.2745        0.7325      0.3947
# HistGradientBoostingClassifier      0.1659        0.8550      0.1382
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.7341      0.3846        0.7881
# LinearDiscriminantAnalysis            0.7445      0.4178        0.7974
# GaussianNB                            0.8282      0.2743        0.8568
# KNeighborsClassifier                  0.8969      0.2358        0.9266
# SVC                                   0.8009      0.3478        0.8414
# LinearSVC                             0.7403      0.3856        0.7955
# SGDClassifier                         0.7471      0.4063        0.8109
# DecisionTreeClassifier                0.8570      0.1946        0.9020
# RandomForestClassifier                0.9031      0.1758        0.9254
# ExtraTreesClassifier                  0.9069      0.1765        0.9292
# BaggingClassifier                     0.8870      0.1732        0.9143
# GradientBoostingClassifier            0.8309      0.2982        0.8762
# AdaBoostClassifier                    0.7922      0.3249        0.8326
# HistGradientBoostingClassifier        0.9018      0.1562        0.9272
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.3990      0.8080    0.3865
# LinearDiscriminantAnalysis          0.4106      0.8201    0.4019
# GaussianNB                          0.2743      0.8713    0.2755
# KNeighborsClassifier                0.2410      0.9355    0.2360
# SVC                                 0.3342      0.8558    0.3316
# LinearSVC                           0.4034      0.8106    0.3929
# SGDClassifier                       0.3896      0.8075    0.4134
# DecisionTreeClassifier              0.2236      0.9048    0.2200
# RandomForestClassifier              0.1838      0.9396    0.1685
# ExtraTreesClassifier                0.1705      0.9361    0.1866
# BaggingClassifier                   0.1739      0.9278    0.1577
# GradientBoostingClassifier          0.3201      0.8855    0.3267
# AdaBoostClassifier                  0.3377      0.8464    0.3269
# HistGradientBoostingClassifier      0.1946      0.9366    0.1724
# Train vs validation results for BorderlineSMOTE technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.1543      0.0000        0.6279
# LinearDiscriminantAnalysis            0.2867      0.0811        0.6666
# GaussianNB                            0.4207      0.2789        0.6979
# KNeighborsClassifier                  0.4510      0.1832        0.8058
# SVC                                   0.1373      0.0000        0.7444
# LinearSVC                             0.0132      0.0000        0.6347
# SGDClassifier                         0.0463      0.0000        0.6289
# DecisionTreeClassifier                0.4650      0.1136        0.7659
# RandomForestClassifier                0.4530      0.1093        0.8101
# ExtraTreesClassifier                  0.4886      0.1316        0.8284
# BaggingClassifier                     0.4158      0.0538        0.7777
# GradientBoostingClassifier            0.2794      0.0282        0.7180
# AdaBoostClassifier                    0.1568      0.0592        0.6727
# HistGradientBoostingClassifier        0.4091      0.1374        0.7948
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.3933        0.7588      0.4050
# LinearDiscriminantAnalysis          0.3717        0.7807      0.4328
# GaussianNB                          0.2806        0.7941      0.2802
# KNeighborsClassifier                0.2697        0.8941      0.2642
# SVC                                 0.3529        0.8348      0.3630
# LinearSVC                           0.3788        0.7665      0.3963
# SGDClassifier                       0.4204        0.7508      0.4076
# DecisionTreeClassifier              0.1717        0.8492      0.1483
# RandomForestClassifier              0.1914        0.8961      0.1786
# ExtraTreesClassifier                0.1628        0.9021      0.1106
# BaggingClassifier                   0.0995        0.8723      0.1659
# GradientBoostingClassifier          0.1269        0.8293      0.2191
# AdaBoostClassifier                  0.2675        0.7872      0.3215
# HistGradientBoostingClassifier      0.1435        0.8920      0.1675
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.8161      0.3868        0.8606
# LinearDiscriminantAnalysis            0.8302      0.4201        0.8657
# GaussianNB                            0.8448      0.2806        0.8750
# KNeighborsClassifier                  0.9310      0.2491        0.9464
# SVC                                   0.8760      0.3549        0.8987
# LinearSVC                             0.8231      0.3955        0.8664
# SGDClassifier                         0.8355      0.3869        0.8576
# DecisionTreeClassifier                0.8898      0.1875        0.9142
# RandomForestClassifier                0.9264      0.1923        0.9438
# ExtraTreesClassifier                  0.9292      0.1899        0.9435
# BaggingClassifier                     0.9094      0.1556        0.9283
# GradientBoostingClassifier            0.8741      0.2439        0.9038
# AdaBoostClassifier                    0.8401      0.3314        0.8766
# HistGradientBoostingClassifier        0.9243      0.1739        0.9402
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.4212      0.8725    0.4068
# LinearDiscriminantAnalysis          0.4113      0.8783    0.4030
# GaussianNB                          0.2826      0.8855    0.2806
# KNeighborsClassifier                0.2660      0.9527    0.2534
# SVC                                 0.3433      0.8975    0.3529
# LinearSVC                           0.4122      0.8795    0.4061
# SGDClassifier                       0.4286      0.8830    0.4201
# DecisionTreeClassifier              0.2016      0.9198    0.2033
# RandomForestClassifier              0.1883      0.9500    0.1883
# ExtraTreesClassifier                0.1674      0.9541    0.1867
# BaggingClassifier                   0.2212      0.9393    0.1562
# GradientBoostingClassifier          0.2658      0.9088    0.3006
# AdaBoostClassifier                  0.3161      0.8833    0.3177
# HistGradientBoostingClassifier      0.1709      0.9447    0.1688
# Train vs validation results for SVMSMOTE technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0874      0.0000        0.4873
# LinearDiscriminantAnalysis            0.2083      0.0843        0.5501
# GaussianNB                            0.3775      0.2797        0.6209
# KNeighborsClassifier                  0.3404      0.1613        0.7493
# SVC                                   0.0079      0.0000        0.5971
# LinearSVC                             0.0000      0.0000        0.4694
# SGDClassifier                         0.0269      0.1087        0.4042
# DecisionTreeClassifier                0.3976      0.0691        0.6977
# RandomForestClassifier                0.3689      0.1117        0.7458
# ExtraTreesClassifier                  0.4040      0.1337        0.7675
# BaggingClassifier                     0.3122      0.0838        0.7153
# GradientBoostingClassifier            0.1807      0.0000        0.6521
# AdaBoostClassifier                    0.0993      0.0000        0.5697
# HistGradientBoostingClassifier        0.3248      0.0838        0.7262
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.2597        0.6712      0.3763
# LinearDiscriminantAnalysis          0.2754        0.6991      0.3966
# GaussianNB                          0.2814        0.7265      0.2865
# KNeighborsClassifier                0.2889        0.8324      0.2419
# SVC                                 0.2336        0.7552      0.3612
# LinearSVC                           0.2093        0.6772      0.3873
# SGDClassifier                       0.2212        0.6615      0.3810
# DecisionTreeClassifier              0.0676        0.7922      0.1674
# RandomForestClassifier              0.1485        0.8411      0.1422
# ExtraTreesClassifier                0.1699        0.8491      0.1422
# BaggingClassifier                   0.1263        0.8065      0.1382
# GradientBoostingClassifier          0.1064        0.7510      0.2347
# AdaBoostClassifier                  0.1422        0.7056      0.2996
# HistGradientBoostingClassifier      0.1026        0.8289      0.1620
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.7440      0.4050        0.8012
# LinearDiscriminantAnalysis            0.7692      0.4367        0.8163
# GaussianNB                            0.7861      0.2802        0.8258
# KNeighborsClassifier                  0.8818      0.2471        0.9132
# SVC                                   0.8152      0.3691        0.8585
# LinearSVC                             0.7541      0.4012        0.8094
# SGDClassifier                         0.7499      0.4268        0.8246
# DecisionTreeClassifier                0.8314      0.2263        0.8757
# RandomForestClassifier                0.8856      0.2045        0.9131
# ExtraTreesClassifier                  0.8880      0.2009        0.9164
# BaggingClassifier                     0.8549      0.1659        0.8920
# GradientBoostingClassifier            0.8150      0.2282        0.8585
# AdaBoostClassifier                    0.7849      0.3378        0.8272
# HistGradientBoostingClassifier        0.8747      0.1389        0.9084
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.3959      0.8121    0.3868
# LinearDiscriminantAnalysis          0.4213      0.8264    0.4121
# GaussianNB                          0.2810      0.8389    0.2798
# KNeighborsClassifier                0.2660      0.9214    0.2698
# SVC                                 0.3616      0.8744    0.3560
# LinearSVC                           0.3924      0.8232    0.3835
# SGDClassifier                       0.4155      0.8292    0.4156
# DecisionTreeClassifier              0.1717      0.8876    0.1502
# RandomForestClassifier              0.1739      0.9173    0.1948
# ExtraTreesClassifier                0.1528      0.9222    0.1667
# BaggingClassifier                   0.1157      0.9042    0.1957
# GradientBoostingClassifier          0.2075      0.8686    0.2456
# AdaBoostClassifier                  0.3459      0.8290    0.3495
# HistGradientBoostingClassifier      0.1339      0.9172    0.1802
# Train vs validation results for SMOTENC technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.1373      0.0000        0.5798
# LinearDiscriminantAnalysis            0.1782      0.0000        0.5602
# GaussianNB                            0.4227      0.2669        0.6870
# KNeighborsClassifier                  0.3464      0.1309        0.7733
# SVC                                   0.0182      0.0000        0.6424
# LinearSVC                             0.0664      0.0000        0.5716
# SGDClassifier                         0.0930      0.0000        0.5520
# DecisionTreeClassifier                0.4226      0.2064        0.7296
# RandomForestClassifier                0.3776      0.0798        0.7670
# ExtraTreesClassifier                  0.4291      0.1302        0.7703
# BaggingClassifier                     0.3276      0.0278        0.7375
# GradientBoostingClassifier            0.2785      0.0000        0.6438
# AdaBoostClassifier                    0.1595      0.0000        0.5784
# HistGradientBoostingClassifier        0.3789      0.0833        0.7443
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.3252        0.7068      0.3746
# LinearDiscriminantAnalysis          0.2532        0.7064      0.3746
# GaussianNB                          0.2395        0.7871      0.2395
# KNeighborsClassifier                0.1969        0.8617      0.1812
# SVC                                 0.2521        0.7626      0.3025
# LinearSVC                           0.2754        0.7182      0.3698
# SGDClassifier                       0.2041        0.6692      0.3550
# DecisionTreeClassifier              0.2579        0.8316      0.0772
# RandomForestClassifier              0.1345        0.8585      0.1250
# ExtraTreesClassifier                0.1339        0.8541      0.2024
# BaggingClassifier                   0.1364        0.8387      0.1152
# GradientBoostingClassifier          0.1478        0.7600      0.2918
# AdaBoostClassifier                  0.2600        0.7281      0.2970
# HistGradientBoostingClassifier      0.1395        0.8529      0.1304
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.7572      0.3561        0.7896
# LinearDiscriminantAnalysis            0.7583      0.3740        0.7966
# GaussianNB                            0.8373      0.2395        0.8687
# KNeighborsClassifier                  0.8995      0.1993        0.9229
# SVC                                   0.8007      0.3165        0.8370
# LinearSVC                             0.7628      0.3561        0.7959
# SGDClassifier                         0.7618      0.3467        0.8053
# DecisionTreeClassifier                0.8692      0.1190        0.9005
# RandomForestClassifier                0.9012      0.1544        0.9216
# ExtraTreesClassifier                  0.8989      0.1931        0.9186
# BaggingClassifier                     0.8878      0.1496        0.9170
# GradientBoostingClassifier            0.8247      0.2414        0.8567
# AdaBoostClassifier                    0.7875      0.3333        0.8203
# HistGradientBoostingClassifier        0.8999      0.1695        0.9270
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.3476      0.8162    0.3488
# LinearDiscriminantAnalysis          0.3856      0.8176    0.3571
# GaussianNB                          0.2395      0.8808    0.2395
# KNeighborsClassifier                0.2063      0.9318    0.2012
# SVC                                 0.2967      0.8538    0.3056
# LinearSVC                           0.3590      0.8190    0.3479
# SGDClassifier                       0.3417      0.8108    0.3365
# DecisionTreeClassifier              0.2372      0.9099    0.1807
# RandomForestClassifier              0.2037      0.9343    0.1718
# ExtraTreesClassifier                0.1901      0.9277    0.2015
# BaggingClassifier                   0.1717      0.9215    0.1709
# GradientBoostingClassifier          0.2960      0.8721    0.3012
# AdaBoostClassifier                  0.3101      0.8357    0.3125
# HistGradientBoostingClassifier      0.1550      0.9356    0.1931
# Train vs validation results for ADASYN technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0642      0.0000        0.4926
# LinearDiscriminantAnalysis            0.1485      0.0286        0.5354
# GaussianNB                            0.4129      0.2751        0.6741
# KNeighborsClassifier                  0.2990      0.2094        0.7544
# SVC                                   0.0013      0.0000        0.5489
# LinearSVC                             0.0000      0.0000        0.4743
# SGDClassifier                         0.0078      0.0000        0.3552
# DecisionTreeClassifier                0.4016      0.1382        0.7129
# RandomForestClassifier                0.3480      0.0820        0.7613
# ExtraTreesClassifier                  0.4207      0.1323        0.7627
# BaggingClassifier                     0.3038      0.0833        0.7003
# GradientBoostingClassifier            0.1770      0.0000        0.6271
# AdaBoostClassifier                    0.1009      0.0000        0.5415
# HistGradientBoostingClassifier        0.2870      0.1117        0.7239
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.3774        0.6820      0.4030
# LinearDiscriminantAnalysis          0.3717        0.6986      0.4252
# GaussianNB                          0.2740        0.7705      0.2743
# KNeighborsClassifier                0.2425        0.8538      0.2475
# SVC                                 0.2964        0.7493      0.3448
# LinearSVC                           0.3953        0.6886      0.4018
# SGDClassifier                       0.0000        0.6463      0.4201
# DecisionTreeClassifier              0.1489        0.8149      0.1498
# RandomForestClassifier              0.1754        0.8535      0.1464
# ExtraTreesClassifier                0.1549        0.8629      0.1417
# BaggingClassifier                   0.1163        0.8306      0.1163
# GradientBoostingClassifier          0.1456        0.7797      0.2713
# AdaBoostClassifier                  0.3414        0.7167      0.3548
# HistGradientBoostingClassifier      0.1667        0.8406      0.1515
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.7468      0.3958        0.7879
# LinearDiscriminantAnalysis            0.7587      0.4113        0.7955
# GaussianNB                            0.8287      0.2743        0.8550
# KNeighborsClassifier                  0.8959      0.2454        0.9218
# SVC                                   0.8084      0.3492        0.8418
# LinearSVC                             0.7549      0.4134        0.7937
# SGDClassifier                         0.7366      0.4122        0.8080
# DecisionTreeClassifier                0.8722      0.1793        0.9020
# RandomForestClassifier                0.8995      0.1538        0.9215
# ExtraTreesClassifier                  0.9009      0.2140        0.9248
# BaggingClassifier                     0.8863      0.0664        0.9158
# GradientBoostingClassifier            0.8348      0.3084        0.8727
# AdaBoostClassifier                    0.7975      0.3279        0.8329
# HistGradientBoostingClassifier        0.8932      0.1245        0.9162
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.3922      0.8100    0.4048
# LinearDiscriminantAnalysis          0.4077      0.8171    0.4060
# GaussianNB                          0.2717      0.8656    0.2717
# KNeighborsClassifier                0.2259      0.9311    0.2609
# SVC                                 0.3351      0.8539    0.3426
# LinearSVC                           0.4024      0.8136    0.4019
# SGDClassifier                       0.4125      0.7916    0.4057
# DecisionTreeClassifier              0.1255      0.9090    0.1562
# RandomForestClassifier              0.2007      0.9286    0.2206
# ExtraTreesClassifier                0.2030      0.9295    0.2022
# BaggingClassifier                   0.1142      0.9182    0.1489
# GradientBoostingClassifier          0.2462      0.8786    0.3254
# AdaBoostClassifier                  0.3247      0.8386    0.3157
# HistGradientBoostingClassifier      0.2022      0.9322    0.1875
# Train vs validation results for RandomUnderSampler technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0730      0.0000        0.5432
# LinearDiscriminantAnalysis            0.1874      0.0281        0.5856
# GaussianNB                            0.4097      0.2703        0.6718
# KNeighborsClassifier                  0.1442      0.1685        0.4802
# SVC                                   0.0000      0.0000        0.5200
# LinearSVC                             0.0000      0.0000        0.5533
# SGDClassifier                         0.0705      0.0000        0.5503
# DecisionTreeClassifier                0.2843      0.1891        0.4748
# RandomForestClassifier                0.1673      0.1058        0.4742
# ExtraTreesClassifier                  0.1638      0.1232        0.4530
# BaggingClassifier                     0.1526      0.1053        0.4520
# GradientBoostingClassifier            0.1123      0.0562        0.5249
# AdaBoostClassifier                    0.1237      0.0289        0.5115
# HistGradientBoostingClassifier        0.1636      0.0529        0.5013
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.3710        0.6728      0.4094
# LinearDiscriminantAnalysis          0.3960        0.7004      0.4190
# GaussianNB                          0.2581        0.7654      0.2548
# KNeighborsClassifier                0.3036        0.6506      0.3324
# SVC                                 0.3636        0.6997      0.3944
# LinearSVC                           0.3684        0.6770      0.4143
# SGDClassifier                       0.1732        0.6343      0.3872
# DecisionTreeClassifier              0.1964        0.6079      0.2710
# RandomForestClassifier              0.2669        0.6342      0.3343
# ExtraTreesClassifier                0.2901        0.5794      0.2809
# BaggingClassifier                   0.2830        0.6097      0.3107
# GradientBoostingClassifier          0.3261        0.6616      0.3295
# AdaBoostClassifier                  0.3546        0.6632      0.3030
# HistGradientBoostingClassifier      0.2669        0.6531      0.2941
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.7352      0.3916        0.7687
# LinearDiscriminantAnalysis            0.7388      0.4113        0.7716
# GaussianNB                            0.8115      0.2494        0.8445
# KNeighborsClassifier                  0.7170      0.3365        0.7930
# SVC                                   0.7641      0.3771        0.7988
# LinearSVC                             0.7359      0.4005        0.7674
# SGDClassifier                         0.6267      0.2648        0.7030
# DecisionTreeClassifier                0.6428      0.3125        0.6722
# RandomForestClassifier                0.6772      0.3741        0.7093
# ExtraTreesClassifier                  0.6222      0.3309        0.6723
# BaggingClassifier                     0.6708      0.3358        0.6803
# GradientBoostingClassifier            0.7140      0.3118        0.7523
# AdaBoostClassifier                    0.7249      0.3294        0.7540
# HistGradientBoostingClassifier        0.6865      0.3173        0.7551
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.3947      0.7749    0.3837
# LinearDiscriminantAnalysis          0.4028      0.7808    0.3941
# GaussianNB                          0.2484      0.8550    0.2478
# KNeighborsClassifier                0.3354      0.8128    0.3340
# SVC                                 0.3625      0.8168    0.3622
# LinearSVC                           0.3910      0.7776    0.3846
# SGDClassifier                       0.3423      0.6854    0.3539
# DecisionTreeClassifier              0.2758      0.6476    0.2975
# RandomForestClassifier              0.3524      0.7428    0.3433
# ExtraTreesClassifier                0.3414      0.7069    0.3320
# BaggingClassifier                   0.3167      0.7067    0.3111
# GradientBoostingClassifier          0.3524      0.7507    0.3254
# AdaBoostClassifier                  0.3284      0.7742    0.3012
# HistGradientBoostingClassifier      0.3132      0.7695    0.3407

# %%
sample_vs = [x/10 for x in range(1, 10, 2)]+[1]
for resampling_tq in resampling_tqs_no_ss:
    resampling_tq_str = str(resampling_tq).split('.')[-1][:-2]
    print(f'Train vs validation results for {resampling_tq_str} technique.')
    display(get_train_val_results_for_sampling(resampling_tq, 
                                               tqs_wo_random_state, 
                                               sample_vs, 
                                               models, 
                                               X_train, y_train, 
                                               splitter, 
                                               X_val, y_val, 
                                               ss=False))
    print()
# Out:
# Train vs validation results for CondensedNearestNeighbour technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0127      0.0000        0.0127
# LinearDiscriminantAnalysis            0.0202      0.0000        0.0202
# GaussianNB                            0.4079      0.2972        0.4079
# KNeighborsClassifier                  0.1163      0.1381        0.1163
# SVC                                   0.0000      0.0000        0.0000
# LinearSVC                             0.0026      0.0000        0.0026
# SGDClassifier                         0.3503      0.1892        0.3503
# DecisionTreeClassifier                0.2289      0.1661        0.2289
# RandomForestClassifier                0.1111      0.0802        0.1111
# ExtraTreesClassifier                  0.1148      0.1244        0.1148
# BaggingClassifier                     0.1163      0.1485        0.1163
# GradientBoostingClassifier            0.1076      0.0559        0.1076
# AdaBoostClassifier                    0.1021      0.0296        0.1021
# HistGradientBoostingClassifier        0.1380      0.1359        0.1380
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.0000        0.0127      0.0000
# LinearDiscriminantAnalysis          0.0000        0.0202      0.0000
# GaussianNB                          0.2972        0.4079      0.2972
# KNeighborsClassifier                0.1381        0.1163      0.1381
# SVC                                 0.0000        0.0000      0.0000
# LinearSVC                           0.0000        0.0026      0.0000
# SGDClassifier                       0.1892        0.3503      0.1892
# DecisionTreeClassifier              0.1661        0.2289      0.1661
# RandomForestClassifier              0.0802        0.1111      0.0802
# ExtraTreesClassifier                0.1244        0.1148      0.1244
# BaggingClassifier                   0.1485        0.1163      0.1485
# GradientBoostingClassifier          0.0559        0.1076      0.0559
# AdaBoostClassifier                  0.0296        0.1021      0.0296
# HistGradientBoostingClassifier      0.1359        0.1380      0.1359
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.0127      0.0000        0.0127
# LinearDiscriminantAnalysis            0.0202      0.0000        0.0202
# GaussianNB                            0.4079      0.2972        0.4079
# KNeighborsClassifier                  0.1163      0.1381        0.1163
# SVC                                   0.0000      0.0000        0.0000
# LinearSVC                             0.0026      0.0000        0.0026
# SGDClassifier                         0.3503      0.1892        0.3503
# DecisionTreeClassifier                0.2289      0.1661        0.2289
# RandomForestClassifier                0.1111      0.0802        0.1111
# ExtraTreesClassifier                  0.1148      0.1244        0.1148
# BaggingClassifier                     0.1163      0.1485        0.1163
# GradientBoostingClassifier            0.1076      0.0559        0.1076
# AdaBoostClassifier                    0.1021      0.0296        0.1021
# HistGradientBoostingClassifier        0.1380      0.1359        0.1380
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.0000      0.0127    0.0000
# LinearDiscriminantAnalysis          0.0000      0.0202    0.0000
# GaussianNB                          0.2972      0.4079    0.2972
# KNeighborsClassifier                0.1381      0.1163    0.1381
# SVC                                 0.0000      0.0000    0.0000
# LinearSVC                           0.0000      0.0026    0.0000
# SGDClassifier                       0.1892      0.3503    0.1892
# DecisionTreeClassifier              0.1661      0.2289    0.1661
# RandomForestClassifier              0.0802      0.1111    0.0802
# ExtraTreesClassifier                0.1244      0.1148    0.1244
# BaggingClassifier                   0.1485      0.1163    0.1485
# GradientBoostingClassifier          0.0559      0.1076    0.0559
# AdaBoostClassifier                  0.0296      0.1021    0.0296
# HistGradientBoostingClassifier      0.1359      0.1380    0.1359
# Train vs validation results for TomekLinks technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0000      0.0000        0.0000
# LinearDiscriminantAnalysis            0.0818      0.0000        0.0818
# GaussianNB                            0.2711      0.2725        0.2711
# KNeighborsClassifier                  0.1084      0.0867        0.1084
# SVC                                   0.0000      0.0000        0.0000
# LinearSVC                             0.0000      0.0000        0.0000
# SGDClassifier                         0.0000      0.0000        0.0000
# DecisionTreeClassifier                0.2181      0.2036        0.2181
# RandomForestClassifier                0.1310      0.0568        0.1310
# ExtraTreesClassifier                  0.1603      0.1351        0.1603
# BaggingClassifier                     0.0947      0.0578        0.0947
# GradientBoostingClassifier            0.0372      0.0000        0.0372
# AdaBoostClassifier                    0.0075      0.0000        0.0075
# HistGradientBoostingClassifier        0.0891      0.0292        0.0891
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.0000        0.0000      0.0000
# LinearDiscriminantAnalysis          0.0000        0.0818      0.0000
# GaussianNB                          0.2725        0.2711      0.2725
# KNeighborsClassifier                0.0867        0.1084      0.0867
# SVC                                 0.0000        0.0000      0.0000
# LinearSVC                           0.0000        0.0000      0.0000
# SGDClassifier                       0.0000        0.0000      0.0000
# DecisionTreeClassifier              0.2036        0.2181      0.2036
# RandomForestClassifier              0.0568        0.1310      0.0568
# ExtraTreesClassifier                0.1351        0.1603      0.1351
# BaggingClassifier                   0.0578        0.0947      0.0578
# GradientBoostingClassifier          0.0000        0.0372      0.0000
# AdaBoostClassifier                  0.0000        0.0075      0.0000
# HistGradientBoostingClassifier      0.0292        0.0891      0.0292
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.0000      0.0000        0.0000
# LinearDiscriminantAnalysis            0.0818      0.0000        0.0818
# GaussianNB                            0.2711      0.2725        0.2711
# KNeighborsClassifier                  0.1084      0.0867        0.1084
# SVC                                   0.0000      0.0000        0.0000
# LinearSVC                             0.0000      0.0000        0.0000
# SGDClassifier                         0.0000      0.0000        0.0000
# DecisionTreeClassifier                0.2181      0.2036        0.2181
# RandomForestClassifier                0.1310      0.0568        0.1310
# ExtraTreesClassifier                  0.1603      0.1351        0.1603
# BaggingClassifier                     0.0947      0.0578        0.0947
# GradientBoostingClassifier            0.0372      0.0000        0.0372
# AdaBoostClassifier                    0.0075      0.0000        0.0075
# HistGradientBoostingClassifier        0.0891      0.0292        0.0891
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.0000      0.0000    0.0000
# LinearDiscriminantAnalysis          0.0000      0.0818    0.0000
# GaussianNB                          0.2725      0.2711    0.2725
# KNeighborsClassifier                0.0867      0.1084    0.0867
# SVC                                 0.0000      0.0000    0.0000
# LinearSVC                           0.0000      0.0000    0.0000
# SGDClassifier                       0.0000      0.0000    0.0000
# DecisionTreeClassifier              0.2036      0.2181    0.2036
# RandomForestClassifier              0.0568      0.1310    0.0568
# ExtraTreesClassifier                0.1351      0.1603    0.1351
# BaggingClassifier                   0.0578      0.0947    0.0578
# GradientBoostingClassifier          0.0000      0.0372    0.0000
# AdaBoostClassifier                  0.0000      0.0075    0.0000
# HistGradientBoostingClassifier      0.0292      0.0891    0.0292
# Train vs validation results for EditedNearestNeighbours technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0922      0.0000        0.0922
# LinearDiscriminantAnalysis            0.2692      0.1309        0.2692
# GaussianNB                            0.2965      0.2725        0.2965
# KNeighborsClassifier                  0.2439      0.2030        0.2439
# SVC                                   0.0000      0.0000        0.0000
# LinearSVC                             0.0000      0.0000        0.0000
# SGDClassifier                         0.0232      0.0000        0.0232
# DecisionTreeClassifier                0.3905      0.2350        0.3905
# RandomForestClassifier                0.3077      0.1741        0.3077
# ExtraTreesClassifier                  0.3358      0.2027        0.3358
# BaggingClassifier                     0.2778      0.1238        0.2778
# GradientBoostingClassifier            0.2129      0.1081        0.2129
# AdaBoostClassifier                    0.1609      0.0272        0.1609
# HistGradientBoostingClassifier        0.3037      0.1651        0.3037
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.0000        0.0922      0.0000
# LinearDiscriminantAnalysis          0.1309        0.2692      0.1309
# GaussianNB                          0.2725        0.2965      0.2725
# KNeighborsClassifier                0.2030        0.2439      0.2030
# SVC                                 0.0000        0.0000      0.0000
# LinearSVC                           0.0000        0.0000      0.0000
# SGDClassifier                       0.0000        0.0232      0.0000
# DecisionTreeClassifier              0.2350        0.3905      0.2350
# RandomForestClassifier              0.1741        0.3077      0.1741
# ExtraTreesClassifier                0.2027        0.3358      0.2027
# BaggingClassifier                   0.1238        0.2778      0.1238
# GradientBoostingClassifier          0.1081        0.2129      0.1081
# AdaBoostClassifier                  0.0272        0.1609      0.0272
# HistGradientBoostingClassifier      0.1651        0.3037      0.1651
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.0922      0.0000        0.0922
# LinearDiscriminantAnalysis            0.2692      0.1309        0.2692
# GaussianNB                            0.2965      0.2725        0.2965
# KNeighborsClassifier                  0.2439      0.2030        0.2439
# SVC                                   0.0000      0.0000        0.0000
# LinearSVC                             0.0000      0.0000        0.0000
# SGDClassifier                         0.0232      0.0000        0.0232
# DecisionTreeClassifier                0.3905      0.2350        0.3905
# RandomForestClassifier                0.3077      0.1741        0.3077
# ExtraTreesClassifier                  0.3358      0.2027        0.3358
# BaggingClassifier                     0.2778      0.1238        0.2778
# GradientBoostingClassifier            0.2129      0.1081        0.2129
# AdaBoostClassifier                    0.1609      0.0272        0.1609
# HistGradientBoostingClassifier        0.3037      0.1651        0.3037
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.0000      0.0922    0.0000
# LinearDiscriminantAnalysis          0.1309      0.2692    0.1309
# GaussianNB                          0.2725      0.2965    0.2725
# KNeighborsClassifier                0.2030      0.2439    0.2030
# SVC                                 0.0000      0.0000    0.0000
# LinearSVC                           0.0000      0.0000    0.0000
# SGDClassifier                       0.0000      0.0232    0.0000
# DecisionTreeClassifier              0.2350      0.3905    0.2350
# RandomForestClassifier              0.1741      0.3077    0.1741
# ExtraTreesClassifier                0.2027      0.3358    0.2027
# BaggingClassifier                   0.1238      0.2778    0.1238
# GradientBoostingClassifier          0.1081      0.2129    0.1081
# AdaBoostClassifier                  0.0272      0.1609    0.0272
# HistGradientBoostingClassifier      0.1651      0.3037    0.1651
# Train vs validation results for NeighbourhoodCleaningRule technique.
#                                 ss=0.1 train  ss=0.1 val  ss=0.3 train  \
# Models
# LogisticRegression                    0.0991      0.0000        0.0991
# LinearDiscriminantAnalysis            0.2759      0.1295        0.2759
# GaussianNB                            0.2966      0.2725        0.2966
# KNeighborsClassifier                  0.2465      0.1562        0.2465
# SVC                                   0.0203      0.0000        0.0203
# LinearSVC                             0.0000      0.0000        0.0000
# SGDClassifier                         0.0225      0.0000        0.0225
# DecisionTreeClassifier                0.3717      0.1815        0.3717
# RandomForestClassifier                0.3182      0.1546        0.3182
# ExtraTreesClassifier                  0.3475      0.1651        0.3475
# BaggingClassifier                     0.2757      0.0995        0.2757
# GradientBoostingClassifier            0.2013      0.0806        0.2013
# AdaBoostClassifier                    0.1508      0.0000        0.1508
# HistGradientBoostingClassifier        0.2853      0.1214        0.2853
#
#                                 ss=0.3 val  ss=0.5 train  ss=0.5 val  \
# Models
# LogisticRegression                  0.0000        0.0991      0.0000
# LinearDiscriminantAnalysis          0.1295        0.2759      0.1295
# GaussianNB                          0.2725        0.2966      0.2725
# KNeighborsClassifier                0.1562        0.2465      0.1562
# SVC                                 0.0000        0.0203      0.0000
# LinearSVC                           0.0000        0.0000      0.0000
# SGDClassifier                       0.0000        0.0225      0.0000
# DecisionTreeClassifier              0.1815        0.3717      0.1815
# RandomForestClassifier              0.1546        0.3182      0.1546
# ExtraTreesClassifier                0.1651        0.3475      0.1651
# BaggingClassifier                   0.0995        0.2757      0.0995
# GradientBoostingClassifier          0.0806        0.2013      0.0806
# AdaBoostClassifier                  0.0000        0.1508      0.0000
# HistGradientBoostingClassifier      0.1214        0.2853      0.1214
#
#                                 ss=0.7 train  ss=0.7 val  ss=0.9 train  \
# Models
# LogisticRegression                    0.0991      0.0000        0.0991
# LinearDiscriminantAnalysis            0.2759      0.1295        0.2759
# GaussianNB                            0.2966      0.2725        0.2966
# KNeighborsClassifier                  0.2465      0.1562        0.2465
# SVC                                   0.0203      0.0000        0.0203
# LinearSVC                             0.0000      0.0000        0.0000
# SGDClassifier                         0.0225      0.0000        0.0225
# DecisionTreeClassifier                0.3717      0.1815        0.3717
# RandomForestClassifier                0.3182      0.1546        0.3182
# ExtraTreesClassifier                  0.3475      0.1651        0.3475
# BaggingClassifier                     0.2757      0.0995        0.2757
# GradientBoostingClassifier            0.2013      0.0806        0.2013
# AdaBoostClassifier                    0.1508      0.0000        0.1508
# HistGradientBoostingClassifier        0.2853      0.1214        0.2853
#
#                                 ss=0.9 val  ss=1 train  ss=1 val
# Models
# LogisticRegression                  0.0000      0.0991    0.0000
# LinearDiscriminantAnalysis          0.1295      0.2759    0.1295
# GaussianNB                          0.2725      0.2966    0.2725
# KNeighborsClassifier                0.1562      0.2465    0.1562
# SVC                                 0.0000      0.0203    0.0000
# LinearSVC                           0.0000      0.0000    0.0000
# SGDClassifier                       0.0000      0.0225    0.0000
# DecisionTreeClassifier              0.1815      0.3717    0.1815
# RandomForestClassifier              0.1546      0.3182    0.1546
# ExtraTreesClassifier                0.1651      0.3475    0.1651
# BaggingClassifier                   0.0995      0.2757    0.0995
# GradientBoostingClassifier          0.0806      0.2013    0.0806
# AdaBoostClassifier                  0.0000      0.1508    0.0000
# HistGradientBoostingClassifier      0.1214      0.2853    0.1214

# %% [markdown]
# #### Let's look on the results.
#     Resampling results were chosen based on val results.
#     For validation dataset the constant strategy (dummy classification) which choose only 1 gives ~0.2045 f2_score so let's focus on higher ones.
#     SMOTE
#         ss=0.5
#             Model	train score / val score
#             LinearDiscriminantAnalysis 0.7039	0.4303
#             LinearSVC 0.6979	0.4054
#             SGDClassifier 0.6860	0.4084
#             AdaBoostClassifier 0.7325	0.3947
#
#     BorderlineSMOTE
#         ss=0.3
#             LogisticRegression 0.6279	0.3933
#             SGDClassifier 0.6289	0.4204
#
#         ss=0.5
#             LinearDiscriminantAnalysis 0.7807	0.4328
#             LinearSVC 0.7665	0.3963
#
#     SVMSMOTE
#         ss=0.7
#             LinearDiscriminantAnalysis 0.7692	0.4367
#             LinearSVC 0.7541	0.4012
#             SGDClassifier 0.7499	0.4268
#
#     SMOTENC
#         ss=0.5
#             LogisticRegression 0.7068	0.3746
#             LinearDiscriminantAnalysis 0.7064	0.3746
#             LinearSVC 0.7626	0.3025
#
#     ADASYN
#         ss=0.5
#             LogisticRegression 0.6820	0.4030
#             LinearDiscriminantAnalysis 0.6986	0.4252
#             LinearSVC 0.6886	0.4018
#             SGDClassifier 0.6463	0.4201
#             AdaBoostClassifier 0.7167	0.3548
#
#     RandomUnderSampler
#         ss=0.5
#             LogisticRegression 0.6728	0.4094
#             LinearDiscriminantAnalysis 0.7004	0.4190
#             SVC 0.6997	0.3944
#             LinearSVC 0.6770	0.4143
#             SGDClassifier 0.6343	0.3872
#             RandomForestClassifier 0.6342	0.3343
#             GradientBoostingClassifier 0.6616	0.3295
#
#         ss=0.7
#             BaggingClassifier 0.6708	0.3358
#
#
#     CondensedNearestNeighbour
#         not sufficient
#
#     TomekLinks
#         not sufficient
#
#     EditedNearestNeighbours
#         not sufficient
#
#     NeighbourhoodCleaningRule
#         not sufficient

# %% [markdown]
# Let's give a chance for some combinations:<br>
# &emsp;&emsp;It seems SMOTE performs better than BorderlineSMOTE so there is no needs to check them both.<br>
# &emsp;&emsp;Similar for SMOTE and SMOTENC.<br>
# &emsp;&emsp;For undersampling only RandomUnderSampler showed some interesting results.<br>
# Combinations to check:<br>
# &emsp;&emsp;SMOTE + RandomUnderSampler<br>
# &emsp;&emsp;SVMSMOTE + RandomUnderSampler<br>
# &emsp;&emsp;ADASYN + RandomUnderSampler<br>

# %%
from imblearn.pipeline import Pipeline as imPipeline

# %%
# effective (over/under)sampling techniques
oversample_tqs = [SMOTE, SVMSMOTE, ADASYN]
undersample_tqs = [RandomUnderSampler]

# effective models
models_new = [
    LogisticRegression(random_state=24),
    LinearDiscriminantAnalysis(),
    SVC(),
    LinearSVC(),
    SGDClassifier(random_state=24),
    RandomForestClassifier(random_state=24),
    BaggingClassifier(random_state=24),
    GradientBoostingClassifier(random_state=24),
    AdaBoostClassifier(random_state=24)
]

# %%
def get_train_val_results_for_combined_resampling(oversampling_tq, undersampling_tq, oversample_vs, undersample_vs,
                                                  models, X, y, splitter, X_val, y_val):
    ''' Get scores for models based on cross_val_score on train dataset 
        and prediction scores for valudation dataset
        based on resampling technique and sampling strategies.
    Parameters:
        oversampling_tq   - oversampling technique
        undersampling_tq  - undersampling technique
        oversample_vs     - list of ratios to be used for oversampling
        undersample_vs    - list of ratios to be used for undersampling
        models            - models to evaluate
        X                 - X train dataset
        y                 - y train dataset
        splitter          - cross-validation splitting strategy
        X_val             - X validation dataset
        y_val             - y validation dataset
    Result:
        Dataframe with the coss_val_score and validation results for given models, all resampling techniques
        and ratios of sampling_strategy '''
    
    stq_results = pd.DataFrame()

    for oversample_v in oversample_vs:
        oversample_tq = oversampling_tq(sampling_strategy=oversample_v, random_state=24)
        for undersample_v in undersample_vs:
            # undersampling cannot be performed if len(minority_class)/undersample_v < oversample_v*len(majority_class)
            # because that will require to generate a new sample what is not the purpose of undersampling
            # ADASYN has a little different mechanism of sample generating so need to be separated 
            # actually there is no sense to run a undersample_v >= oversample_v because if they be eq there will
            # be no change in the data structure 
#             if oversampling_tq == ADASYN:
#                 if undersample_v > oversample_v:
#                     undersample_tq = undersampling_tq(sampling_strategy=undersample_v, random_state=24)
#                 else:
#                     continue
            if undersample_v > oversample_v:
                undersample_tq = undersampling_tq(sampling_strategy=undersample_v, random_state=24)
            else:
                continue
            resample_pipeline = imPipeline([('oversampling', oversample_tq), ('undersampling', undersample_tq)])
            X_stq, y_stq = resample_pipeline.fit_resample(X, y)
            sample_v = f'o{oversample_v}/u{undersample_v}'
            stq_scores = get_models_scores_vs_val_for_sampling(models, X_stq, y_stq, splitter, X_val, y_val, sample_v)
            stq_results = pd.concat([stq_results, stq_scores], axis=1)
    return stq_results

# %%
o_sample_vs = [0.3, 0.5, 0.7] # based on the previous research these were pretty efective
u_sample_vs = [0.3, 0.5, 0.7, 1.0] 
for oversampling_tq in oversample_tqs:
    for undersample_tq in undersample_tqs:
        oversampling_tq_str = str(oversampling_tq).split('.')[-1][:-2]
        undersampling_tq_str = str(undersample_tq).split('.')[-1][:-2]

        print(f'Train vs validation results for combined {oversampling_tq_str} and {undersampling_tq_str} techniques.')
        display(get_train_val_results_for_combined_resampling(oversampling_tq, 
                                                   undersample_tq, 
                                                   o_sample_vs,
                                                   u_sample_vs,
                                                   models_new, 
                                                   X_train, y_train, 
                                                   splitter, 
                                                   X_val, y_val))
        print()
# Out:
# Train vs validation results for combined SMOTE and RandomUnderSampler techniques.
#                             ss=o0.3/u0.5 train  ss=o0.3/u0.5 val  \
# Models
# LogisticRegression                      0.6829            0.3881
# LinearDiscriminantAnalysis              0.7014            0.4215
# SVC                                     0.7587            0.3448
# LinearSVC                               0.6911            0.4006
# SGDClassifier                           0.7261            0.3614
# RandomForestClassifier                  0.8358            0.2191
# BaggingClassifier                       0.7880            0.2227
# GradientBoostingClassifier              0.7541            0.2347
# AdaBoostClassifier                      0.7060            0.3628
#
#                             ss=o0.3/u0.7 train  ss=o0.3/u0.7 val  \
# Models
# LogisticRegression                      0.7499            0.3930
# LinearDiscriminantAnalysis              0.7592            0.4047
# SVC                                     0.8060            0.3591
# LinearSVC                               0.7565            0.3968
# SGDClassifier                           0.7622            0.4028
# RandomForestClassifier                  0.8640            0.2055
# BaggingClassifier                       0.8264            0.1971
# GradientBoostingClassifier              0.8172            0.3402
# AdaBoostClassifier                      0.7894            0.3675
#
#                             ss=o0.3/u1.0 train  ss=o0.3/u1.0 val  \
# Models
# LogisticRegression                      0.8125            0.4067
# LinearDiscriminantAnalysis              0.8231            0.4079
# SVC                                     0.8492            0.3874
# LinearSVC                               0.8124            0.4028
# SGDClassifier                           0.7959            0.2273
# RandomForestClassifier                  0.8980            0.2128
# BaggingClassifier                       0.8658            0.2160
# GradientBoostingClassifier              0.8770            0.3867
# AdaBoostClassifier                      0.8412            0.3901
#
#                             ss=o0.5/u0.7 train  ss=o0.5/u0.7 val  \
# Models
# LogisticRegression                      0.7467            0.3878
# LinearDiscriminantAnalysis              0.7520            0.4188
# SVC                                     0.8013            0.3448
# LinearSVC                               0.7503            0.4021
# SGDClassifier                           0.7576            0.4054
# RandomForestClassifier                  0.8908            0.1195
# BaggingClassifier                       0.8671            0.1464
# GradientBoostingClassifier              0.8352            0.3188
# AdaBoostClassifier                      0.7994            0.3457
#
#                             ss=o0.5/u1.0 train  ss=o0.5/u1.0 val  \
# Models
# LogisticRegression                      0.8080            0.4005
# LinearDiscriminantAnalysis              0.8198            0.4009
# SVC                                     0.8418            0.3769
# LinearSVC                               0.8101            0.3947
# SGDClassifier                           0.8142            0.4064
# RandomForestClassifier                  0.9174            0.2048
# BaggingClassifier                       0.8921            0.1654
# GradientBoostingClassifier              0.8802            0.3533
# AdaBoostClassifier                      0.8489            0.3563
#
#                             ss=o0.7/u1.0 train  ss=o0.7/u1.0 val
# Models
# LogisticRegression                      0.8108            0.3957
# LinearDiscriminantAnalysis              0.8229            0.4098
# SVC                                     0.8404            0.3671
# LinearSVC                               0.8150            0.4048
# SGDClassifier                           0.8124            0.3532
# RandomForestClassifier                  0.9274            0.1487
# BaggingClassifier                       0.9056            0.1250
# GradientBoostingClassifier              0.8902            0.3000
# AdaBoostClassifier                      0.8471            0.3285
# Train vs validation results for combined SVMSMOTE and RandomUnderSampler techniques.
#                             ss=o0.3/u0.5 train  ss=o0.3/u0.5 val  \
# Models
# LogisticRegression                      0.7558            0.4012
# LinearDiscriminantAnalysis              0.7719            0.4252
# SVC                                     0.7986            0.3607
# LinearSVC                               0.7638            0.4042
# SGDClassifier                           0.6694            0.4178
# RandomForestClassifier                  0.8393            0.2227
# BaggingClassifier                       0.8076            0.1619
# GradientBoostingClassifier              0.7774            0.2564
# AdaBoostClassifier                      0.7547            0.3896
#
#                             ss=o0.3/u0.7 train  ss=o0.3/u0.7 val  \
# Models
# LogisticRegression                      0.8227            0.4062
# LinearDiscriminantAnalysis              0.8325            0.4255
# SVC                                     0.8360            0.3779
# LinearSVC                               0.8274            0.4121
# SGDClassifier                           0.7783            0.3931
# RandomForestClassifier                  0.8643            0.2182
# BaggingClassifier                       0.8360            0.2612
# GradientBoostingClassifier              0.8250            0.3182
# AdaBoostClassifier                      0.8142            0.3779
#
#                             ss=o0.3/u1.0 train  ss=o0.3/u1.0 val  \
# Models
# LogisticRegression                      0.8608            0.4135
# LinearDiscriminantAnalysis              0.8597            0.4136
# SVC                                     0.8745            0.3786
# LinearSVC                               0.8617            0.4104
# SGDClassifier                           0.8511            0.3827
# RandomForestClassifier                  0.8983            0.2751
# BaggingClassifier                       0.8737            0.2508
# GradientBoostingClassifier              0.8677            0.3482
# AdaBoostClassifier                      0.8622            0.3722
#
#                             ss=o0.5/u0.7 train  ss=o0.5/u0.7 val  \
# Models
# LogisticRegression                      0.8194            0.4178
# LinearDiscriminantAnalysis              0.8313            0.4178
# SVC                                     0.8588            0.3392
# LinearSVC                               0.8267            0.4132
# SGDClassifier                           0.8211            0.3939
# RandomForestClassifier                  0.8886            0.2165
# BaggingClassifier                       0.8558            0.2124
# GradientBoostingClassifier              0.8530            0.3247
# AdaBoostClassifier                      0.8252            0.3790
#
#                             ss=o0.5/u1.0 train  ss=o0.5/u1.0 val  \
# Models
# LogisticRegression                      0.8702            0.4188
# LinearDiscriminantAnalysis              0.8716            0.4136
# SVC                                     0.8827            0.3723
# LinearSVC                               0.8740            0.4094
# SGDClassifier                           0.8657            0.4087
# RandomForestClassifier                  0.9169            0.2105
# BaggingClassifier                       0.8982            0.2273
# GradientBoostingClassifier              0.8930            0.3803
# AdaBoostClassifier                      0.8797            0.3444
#
#                             ss=o0.7/u1.0 train  ss=o0.7/u1.0 val
# Models
# LogisticRegression                      0.8680            0.3995
# LinearDiscriminantAnalysis              0.8701            0.4136
# SVC                                     0.8882            0.3533
# LinearSVC                               0.8711            0.3924
# SGDClassifier                           0.8523            0.3956
# RandomForestClassifier                  0.9300            0.1986
# BaggingClassifier                       0.9130            0.1661
# GradientBoostingClassifier              0.8963            0.3372
# AdaBoostClassifier                      0.8699            0.3562
# Train vs validation results for combined ADASYN and RandomUnderSampler techniques.
#                             ss=o0.3/u0.5 train  ss=o0.3/u0.5 val  \
# Models
# LogisticRegression                      0.6797            0.4018
# LinearDiscriminantAnalysis              0.6962            0.4179
# SVC                                     0.7323            0.3538
# LinearSVC                               0.6885            0.4094
# SGDClassifier                           0.6872            0.3654
# RandomForestClassifier                  0.8277            0.2115
# BaggingClassifier                       0.7794            0.2254
# GradientBoostingClassifier              0.7499            0.3041
# AdaBoostClassifier                      0.7032            0.3692
#
#                             ss=o0.3/u0.7 train  ss=o0.3/u0.7 val  \
# Models
# LogisticRegression                      0.7427            0.4058
# LinearDiscriminantAnalysis              0.7517            0.4061
# SVC                                     0.7798            0.3794
# LinearSVC                               0.7467            0.4124
# SGDClassifier                           0.6838            0.3715
# RandomForestClassifier                  0.8564            0.1923
# BaggingClassifier                       0.8138            0.1498
# GradientBoostingClassifier              0.7926            0.3323
# AdaBoostClassifier                      0.7688            0.3453
#
#                             ss=o0.3/u1.0 train  ss=o0.3/u1.0 val  \
# Models
# LogisticRegression                      0.8014            0.3953
# LinearDiscriminantAnalysis              0.8089            0.4005
# SVC                                     0.8332            0.3738
# LinearSVC                               0.8045            0.4014
# SGDClassifier                           0.7811            0.3890
# RandomForestClassifier                  0.8926            0.2322
# BaggingClassifier                       0.8467            0.2013
# GradientBoostingClassifier              0.8452            0.3856
# AdaBoostClassifier                      0.8215            0.3488
#
#                             ss=o0.5/u0.7 train  ss=o0.5/u0.7 val  \
# Models
# LogisticRegression                      0.7609            0.3979
# LinearDiscriminantAnalysis              0.7693            0.4134
# SVC                                     0.8111            0.3581
# LinearSVC                               0.7676            0.4145
# SGDClassifier                           0.7621            0.4282
# RandomForestClassifier                  0.8855            0.1556
# BaggingClassifier                       0.8529            0.1619
# GradientBoostingClassifier              0.8293            0.2961
# AdaBoostClassifier                      0.7933            0.3388
#
#                             ss=o0.5/u1.0 train  ss=o0.5/u1.0 val  \
# Models
# LogisticRegression                      0.8154            0.4019
# LinearDiscriminantAnalysis              0.8257            0.4032
# SVC                                     0.8416            0.3511
# LinearSVC                               0.8194            0.4060
# SGDClassifier                           0.8000            0.4177
# RandomForestClassifier                  0.9123            0.2249
# BaggingClassifier                       0.8850            0.1667
# GradientBoostingClassifier              0.8814            0.3794
# AdaBoostClassifier                      0.8356            0.3614
#
#                             ss=o0.7/u1.0 train  ss=o0.7/u1.0 val
# Models
# LogisticRegression                      0.8030            0.4028
# LinearDiscriminantAnalysis              0.8123            0.4042
# SVC                                     0.8552            0.3571
# LinearSVC                               0.8072            0.3963
# SGDClassifier                           0.8051            0.4015
# RandomForestClassifier                  0.9255            0.1805
# BaggingClassifier                       0.9090            0.1815
# GradientBoostingClassifier              0.8862            0.3482
# AdaBoostClassifier                      0.8417            0.3519

# %% [markdown]
# #### The results comparing to the previous ones:
#     SMOTE + RandomUnderSampler
#         No better results than only SMOTE
#
#     SVMSMOTE + RandomUnderSampler
#         ss = o0.5/u0.7
#         Model		train score / val score
#         LinearSVC	0.8267	0.4132
#
#     ADASYN + RandomUnderSampler
#         ss = o0.5/u0.7
#         LinearSVC 0.7676	0.4145
#         ss=o0.3/u0.5
#         AdaBoostClassifier	0.7032	0.3692
#
#     ss=o0.3/u1.0
#     GradientBoostingClassifier 0.8452	0.3856
#
#     The ADASYN + RandomUnderSampler with ss = o0.5/u0.7 looks promising.
#     The alternatives are only SMOTE or SVMSMOTE for ss=0.5 and 0.7, respectively.

# %% [markdown]
# ADASYN has a n_neighbors argument which define the number of nearest neighbors used for new samples generation. Let's run some test for chosen setup.

# %%
oversample_v = 0.5
undersample_v = 0.7
nbrs_results = pd.DataFrame()
for nn_no in range(1, 14):
    print('n_neighbors:', nn_no)
    oversample_tq = ADASYN(sampling_strategy=oversample_v, n_neighbors=nn_no, random_state=24)
    undersample_tq = RandomUnderSampler(sampling_strategy=undersample_v, random_state=24)
    resample_pipeline = imPipeline([('oversampling', oversample_tq), ('undersampling', undersample_tq)])
    X_ou, y_ou = resample_pipeline.fit_resample(X_train, y_train)
    sample_v = f'nbrs{nn_no}_o{oversample_v}/u{undersample_v}'
    scores = get_models_scores_vs_val_for_sampling(models, X_ou, y_ou, splitter, X_val, y_val, sample_v)
    nbrs_results = pd.concat([nbrs_results, scores], axis=1)
# Out:
# n_neighbors: 1
# n_neighbors: 2
# n_neighbors: 3
# n_neighbors: 4
# n_neighbors: 5
# n_neighbors: 6
# n_neighbors: 7
# n_neighbors: 8
# n_neighbors: 9
# n_neighbors: 10
# n_neighbors: 11
# n_neighbors: 12
# n_neighbors: 13

# %%
nbrs_results[nbrs_results.columns[:10]]
# Out:
#                                 ss=nbrs1_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7440
# LinearDiscriminantAnalysis                        0.7535
# GaussianNB                                        0.8199
# KNeighborsClassifier                              0.9410
# SVC                                               0.8067
# LinearSVC                                         0.7532
# SGDClassifier                                     0.7419
# DecisionTreeClassifier                            0.8843
# RandomForestClassifier                            0.9313
# ExtraTreesClassifier                              0.9415
# BaggingClassifier                                 0.9136
# GradientBoostingClassifier                        0.8273
# AdaBoostClassifier                                0.7895
# HistGradientBoostingClassifier                    0.9134
#
#                                 ss=nbrs1_o0.5/u0.7 val  \
# Models
# LogisticRegression                              0.3958
# LinearDiscriminantAnalysis                      0.4220
# GaussianNB                                      0.2677
# KNeighborsClassifier                            0.2310
# SVC                                             0.3649
# LinearSVC                                       0.4134
# SGDClassifier                                   0.3944
# DecisionTreeClassifier                          0.3042
# RandomForestClassifier                          0.1556
# ExtraTreesClassifier                            0.1515
# BaggingClassifier                               0.1509
# GradientBoostingClassifier                      0.2760
# AdaBoostClassifier                              0.3662
# HistGradientBoostingClassifier                  0.2767
#
#                                 ss=nbrs2_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7405
# LinearDiscriminantAnalysis                        0.7508
# GaussianNB                                        0.8229
# KNeighborsClassifier                              0.9131
# SVC                                               0.7906
# LinearSVC                                         0.7491
# SGDClassifier                                     0.7463
# DecisionTreeClassifier                            0.8684
# RandomForestClassifier                            0.9134
# ExtraTreesClassifier                              0.9173
# BaggingClassifier                                 0.8825
# GradientBoostingClassifier                        0.8217
# AdaBoostClassifier                                0.7759
# HistGradientBoostingClassifier                    0.8934
#
#                                 ss=nbrs2_o0.5/u0.7 val  \
# Models
# LogisticRegression                              0.3989
# LinearDiscriminantAnalysis                      0.4231
# GaussianNB                                      0.2695
# KNeighborsClassifier                            0.2280
# SVC                                             0.3397
# LinearSVC                                       0.4178
# SGDClassifier                                   0.4101
# DecisionTreeClassifier                          0.1600
# RandomForestClassifier                          0.1195
# ExtraTreesClassifier                            0.0810
# BaggingClassifier                               0.1400
# GradientBoostingClassifier                      0.3459
# AdaBoostClassifier                              0.3421
# HistGradientBoostingClassifier                  0.1724
#
#                                 ss=nbrs3_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7446
# LinearDiscriminantAnalysis                        0.7532
# GaussianNB                                        0.8252
# KNeighborsClassifier                              0.9030
# SVC                                               0.7959
# LinearSVC                                         0.7548
# SGDClassifier                                     0.7547
# DecisionTreeClassifier                            0.8502
# RandomForestClassifier                            0.8972
# ExtraTreesClassifier                              0.9031
# BaggingClassifier                                 0.8698
# GradientBoostingClassifier                        0.8279
# AdaBoostClassifier                                0.7840
# HistGradientBoostingClassifier                    0.8824
#
#                                 ss=nbrs3_o0.5/u0.7 val  \
# Models
# LogisticRegression                              0.3989
# LinearDiscriminantAnalysis                      0.4231
# GaussianNB                                      0.2736
# KNeighborsClassifier                            0.2308
# SVC                                             0.3672
# LinearSVC                                       0.4178
# SGDClassifier                                   0.4187
# DecisionTreeClassifier                          0.1373
# RandomForestClassifier                          0.1373
# ExtraTreesClassifier                            0.1357
# BaggingClassifier                               0.1688
# GradientBoostingClassifier                      0.2932
# AdaBoostClassifier                              0.3646
# HistGradientBoostingClassifier                  0.1504
#
#                                 ss=nbrs4_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7440
# LinearDiscriminantAnalysis                        0.7578
# GaussianNB                                        0.8256
# KNeighborsClassifier                              0.8949
# SVC                                               0.7961
# LinearSVC                                         0.7532
# SGDClassifier                                     0.7383
# DecisionTreeClassifier                            0.8499
# RandomForestClassifier                            0.8917
# ExtraTreesClassifier                              0.9015
# BaggingClassifier                                 0.8626
# GradientBoostingClassifier                        0.8244
# AdaBoostClassifier                                0.7825
# HistGradientBoostingClassifier                    0.8814
#
#                                 ss=nbrs4_o0.5/u0.7 val  \
# Models
# LogisticRegression                              0.4011
# LinearDiscriminantAnalysis                      0.4113
# GaussianNB                                      0.2729
# KNeighborsClassifier                            0.2308
# SVC                                             0.3463
# LinearSVC                                       0.4167
# SGDClassifier                                   0.4098
# DecisionTreeClassifier                          0.2583
# RandomForestClassifier                          0.1383
# ExtraTreesClassifier                            0.1556
# BaggingClassifier                               0.1837
# GradientBoostingClassifier                      0.3035
# AdaBoostClassifier                              0.3552
# HistGradientBoostingClassifier                  0.2399
#
#                                 ss=nbrs5_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7609
# LinearDiscriminantAnalysis                        0.7693
# GaussianNB                                        0.8250
# KNeighborsClassifier                              0.8880
# SVC                                               0.8111
# LinearSVC                                         0.7676
# SGDClassifier                                     0.7621
# DecisionTreeClassifier                            0.8346
# RandomForestClassifier                            0.8855
# ExtraTreesClassifier                              0.8883
# BaggingClassifier                                 0.8529
# GradientBoostingClassifier                        0.8293
# AdaBoostClassifier                                0.7933
# HistGradientBoostingClassifier                    0.8813
#
#                                 ss=nbrs5_o0.5/u0.7 val
# Models
# LogisticRegression                              0.3979
# LinearDiscriminantAnalysis                      0.4134
# GaussianNB                                      0.2740
# KNeighborsClassifier                            0.2687
# SVC                                             0.3581
# LinearSVC                                       0.4145
# SGDClassifier                                   0.4282
# DecisionTreeClassifier                          0.1444
# RandomForestClassifier                          0.1556
# ExtraTreesClassifier                            0.1509
# BaggingClassifier                               0.1619
# GradientBoostingClassifier                      0.2961
# AdaBoostClassifier                              0.3388
# HistGradientBoostingClassifier                  0.1800

# %%
nbrs_results[nbrs_results.columns[10:20]]
# Out:
#                                 ss=nbrs6_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7423
# LinearDiscriminantAnalysis                        0.7546
# GaussianNB                                        0.8249
# KNeighborsClassifier                              0.8844
# SVC                                               0.8042
# LinearSVC                                         0.7515
# SGDClassifier                                     0.7392
# DecisionTreeClassifier                            0.8440
# RandomForestClassifier                            0.8806
# ExtraTreesClassifier                              0.8852
# BaggingClassifier                                 0.8641
# GradientBoostingClassifier                        0.8236
# AdaBoostClassifier                                0.7972
# HistGradientBoostingClassifier                    0.8888
#
#                                 ss=nbrs6_o0.5/u0.7 val  \
# Models
# LogisticRegression                              0.3887
# LinearDiscriminantAnalysis                      0.4124
# GaussianNB                                      0.2732
# KNeighborsClassifier                            0.2727
# SVC                                             0.3482
# LinearSVC                                       0.4058
# SGDClassifier                                   0.4308
# DecisionTreeClassifier                          0.2099
# RandomForestClassifier                          0.1894
# ExtraTreesClassifier                            0.1186
# BaggingClassifier                               0.1613
# GradientBoostingClassifier                      0.2769
# AdaBoostClassifier                              0.3390
# HistGradientBoostingClassifier                  0.1619
#
#                                 ss=nbrs7_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7552
# LinearDiscriminantAnalysis                        0.7647
# GaussianNB                                        0.8261
# KNeighborsClassifier                              0.8854
# SVC                                               0.8005
# LinearSVC                                         0.7633
# SGDClassifier                                     0.7336
# DecisionTreeClassifier                            0.8452
# RandomForestClassifier                            0.8715
# ExtraTreesClassifier                              0.8726
# BaggingClassifier                                 0.8528
# GradientBoostingClassifier                        0.8310
# AdaBoostClassifier                                0.8074
# HistGradientBoostingClassifier                    0.8754
#
#                                 ss=nbrs7_o0.5/u0.7 val  \
# Models
# LogisticRegression                              0.3887
# LinearDiscriminantAnalysis                      0.4124
# GaussianNB                                      0.2747
# KNeighborsClassifier                            0.2827
# SVC                                             0.3601
# LinearSVC                                       0.4026
# SGDClassifier                                   0.3895
# DecisionTreeClassifier                          0.1901
# RandomForestClassifier                          0.2052
# ExtraTreesClassifier                            0.1487
# BaggingClassifier                               0.1509
# GradientBoostingClassifier                      0.3055
# AdaBoostClassifier                              0.3571
# HistGradientBoostingClassifier                  0.1961
#
#                                 ss=nbrs8_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7557
# LinearDiscriminantAnalysis                        0.7660
# GaussianNB                                        0.8248
# KNeighborsClassifier                              0.8826
# SVC                                               0.8120
# LinearSVC                                         0.7622
# SGDClassifier                                     0.7612
# DecisionTreeClassifier                            0.8266
# RandomForestClassifier                            0.8717
# ExtraTreesClassifier                              0.8750
# BaggingClassifier                                 0.8488
# GradientBoostingClassifier                        0.8335
# AdaBoostClassifier                                0.8010
# HistGradientBoostingClassifier                    0.8774
#
#                                 ss=nbrs8_o0.5/u0.7 val  \
# Models
# LogisticRegression                              0.4065
# LinearDiscriminantAnalysis                      0.4156
# GaussianNB                                      0.2729
# KNeighborsClassifier                            0.2932
# SVC                                             0.3482
# LinearSVC                                       0.4090
# SGDClassifier                                   0.4155
# DecisionTreeClassifier                          0.1661
# RandomForestClassifier                          0.2107
# ExtraTreesClassifier                            0.1515
# BaggingClassifier                               0.2400
# GradientBoostingClassifier                      0.2548
# AdaBoostClassifier                              0.3476
# HistGradientBoostingClassifier                  0.2200
#
#                                 ss=nbrs9_o0.5/u0.7 train  \
# Models
# LogisticRegression                                0.7459
# LinearDiscriminantAnalysis                        0.7565
# GaussianNB                                        0.8267
# KNeighborsClassifier                              0.8673
# SVC                                               0.8045
# LinearSVC                                         0.7552
# SGDClassifier                                     0.7246
# DecisionTreeClassifier                            0.8182
# RandomForestClassifier                            0.8643
# ExtraTreesClassifier                              0.8704
# BaggingClassifier                                 0.8447
# GradientBoostingClassifier                        0.8357
# AdaBoostClassifier                                0.8095
# HistGradientBoostingClassifier                    0.8756
#
#                                 ss=nbrs9_o0.5/u0.7 val  \
# Models
# LogisticRegression                              0.3919
# LinearDiscriminantAnalysis                      0.4145
# GaussianNB                                      0.2729
# KNeighborsClassifier                            0.2591
# SVC                                             0.3662
# LinearSVC                                       0.4079
# SGDClassifier                                   0.4177
# DecisionTreeClassifier                          0.1880
# RandomForestClassifier                          0.1758
# ExtraTreesClassifier                            0.1737
# BaggingClassifier                               0.1411
# GradientBoostingClassifier                      0.3584
# AdaBoostClassifier                              0.3286
# HistGradientBoostingClassifier                  0.1754
#
#                                 ss=nbrs10_o0.5/u0.7 train  \
# Models
# LogisticRegression                                 0.7514
# LinearDiscriminantAnalysis                         0.7615
# GaussianNB                                         0.8277
# KNeighborsClassifier                               0.8704
# SVC                                                0.8110
# LinearSVC                                          0.7614
# SGDClassifier                                      0.7402
# DecisionTreeClassifier                             0.8251
# RandomForestClassifier                             0.8781
# ExtraTreesClassifier                               0.8759
# BaggingClassifier                                  0.8458
# GradientBoostingClassifier                         0.8404
# AdaBoostClassifier                                 0.8154
# HistGradientBoostingClassifier                     0.8756
#
#                                 ss=nbrs10_o0.5/u0.7 val
# Models
# LogisticRegression                               0.3898
# LinearDiscriminantAnalysis                       0.4145
# GaussianNB                                       0.2751
# KNeighborsClassifier                             0.2308
# SVC                                              0.3662
# LinearSVC                                        0.4079
# SGDClassifier                                    0.3812
# DecisionTreeClassifier                           0.2069
# RandomForestClassifier                           0.1779
# ExtraTreesClassifier                             0.1533
# BaggingClassifier                                0.2041
# GradientBoostingClassifier                       0.2676
# AdaBoostClassifier                               0.3693
# HistGradientBoostingClassifier                   0.1653

# %%
nbrs_results[nbrs_results.columns[20:]]
# Out:
#                                 ss=nbrs11_o0.5/u0.7 train  \
# Models
# LogisticRegression                                 0.7481
# LinearDiscriminantAnalysis                         0.7583
# GaussianNB                                         0.8281
# KNeighborsClassifier                               0.8762
# SVC                                                0.8142
# LinearSVC                                          0.7562
# SGDClassifier                                      0.7243
# DecisionTreeClassifier                             0.8219
# RandomForestClassifier                             0.8671
# ExtraTreesClassifier                               0.8752
# BaggingClassifier                                  0.8382
# GradientBoostingClassifier                         0.8367
# AdaBoostClassifier                                 0.8123
# HistGradientBoostingClassifier                     0.8733
#
#                                 ss=nbrs11_o0.5/u0.7 val  \
# Models
# LogisticRegression                               0.3930
# LinearDiscriminantAnalysis                       0.4145
# GaussianNB                                       0.2762
# KNeighborsClassifier                             0.2950
# SVC                                              0.3541
# LinearSVC                                        0.4079
# SGDClassifier                                    0.3991
# DecisionTreeClassifier                           0.2390
# RandomForestClassifier                           0.1992
# ExtraTreesClassifier                             0.1992
# BaggingClassifier                                0.2519
# GradientBoostingClassifier                       0.3191
# AdaBoostClassifier                               0.3540
# HistGradientBoostingClassifier                   0.2146
#
#                                 ss=nbrs12_o0.5/u0.7 train  \
# Models
# LogisticRegression                                 0.7392
# LinearDiscriminantAnalysis                         0.7492
# GaussianNB                                         0.8270
# KNeighborsClassifier                               0.8606
# SVC                                                0.8036
# LinearSVC                                          0.7463
# SGDClassifier                                      0.7620
# DecisionTreeClassifier                             0.8362
# RandomForestClassifier                             0.8599
# ExtraTreesClassifier                               0.8666
# BaggingClassifier                                  0.8414
# GradientBoostingClassifier                         0.8261
# AdaBoostClassifier                                 0.8106
# HistGradientBoostingClassifier                     0.8623
#
#                                 ss=nbrs12_o0.5/u0.7 val  \
# Models
# LogisticRegression                               0.3804
# LinearDiscriminantAnalysis                       0.4134
# GaussianNB                                       0.2740
# KNeighborsClassifier                             0.2673
# SVC                                              0.3501
# LinearSVC                                        0.3968
# SGDClassifier                                    0.4192
# DecisionTreeClassifier                           0.2174
# RandomForestClassifier                           0.1575
# ExtraTreesClassifier                             0.1606
# BaggingClassifier                                0.1891
# GradientBoostingClassifier                       0.2797
# AdaBoostClassifier                               0.3363
# HistGradientBoostingClassifier                   0.1681
#
#                                 ss=nbrs13_o0.5/u0.7 train  \
# Models
# LogisticRegression                                 0.7527
# LinearDiscriminantAnalysis                         0.7623
# GaussianNB                                         0.8278
# KNeighborsClassifier                               0.8642
# SVC                                                0.8133
# LinearSVC                                          0.7593
# SGDClassifier                                      0.7142
# DecisionTreeClassifier                             0.8292
# RandomForestClassifier                             0.8714
# ExtraTreesClassifier                               0.8704
# BaggingClassifier                                  0.8443
# GradientBoostingClassifier                         0.8544
# AdaBoostClassifier                                 0.8162
# HistGradientBoostingClassifier                     0.8799
#
#                                 ss=nbrs13_o0.5/u0.7 val
# Models
# LogisticRegression                               0.3784
# LinearDiscriminantAnalysis                       0.4145
# GaussianNB                                       0.2743
# KNeighborsClassifier                             0.3096
# SVC                                              0.3551
# LinearSVC                                        0.3979
# SGDClassifier                                    0.4187
# DecisionTreeClassifier                           0.2778
# RandomForestClassifier                           0.1807
# ExtraTreesClassifier                             0.2236
# BaggingClassifier                                0.2245
# GradientBoostingClassifier                       0.2583
# AdaBoostClassifier                               0.3506
# HistGradientBoostingClassifier                   0.1515

# %% [markdown]
# Looks like the default n_neighbors: 5 gives pretty good results for the validation dataset.

# %% [markdown]
# Let's check it for the SMOTE and SVMSMOTE as well.

# %%
sample_vs = [0.5]
knbrs_results = pd.DataFrame()
print('Train vs validation results for SMOTE technique.')
for kn_no in range(1, 14):
    print('k_neighbors:', kn_no)
    oversample_tq = SMOTE(sampling_strategy=oversample_v, k_neighbors=kn_no, random_state=24)
    X_o, y_o = oversample_tq.fit_resample(X_train, y_train)
    sample_v = f'nbrs{kn_no}_o{sample_vs[0]}'
    results_df = get_models_scores_vs_val_for_sampling(models, X_o, y_o, splitter, X_val, y_val, sample_v)
    knbrs_results = pd.concat([knbrs_results, results_df], axis=1)
# Out:
# Train vs validation results for SMOTE technique.
# k_neighbors: 1
# k_neighbors: 2
# k_neighbors: 3
# k_neighbors: 4
# k_neighbors: 5
# k_neighbors: 6
# k_neighbors: 7
# k_neighbors: 8
# k_neighbors: 9
# k_neighbors: 10
# k_neighbors: 11
# k_neighbors: 12
# k_neighbors: 13

# %%
knbrs_results[knbrs_results.columns[:14]]
# Out:
#                                 ss=nbrs1_o0.5 train  ss=nbrs1_o0.5 val  \
# Models
# LogisticRegression                           0.6861             0.3904
# LinearDiscriminantAnalysis                   0.7056             0.4215
# GaussianNB                                   0.7675             0.2699
# KNeighborsClassifier                         0.9173             0.2555
# SVC                                          0.7651             0.3517
# LinearSVC                                    0.6959             0.4006
# SGDClassifier                                0.6371             0.4167
# DecisionTreeClassifier                       0.8687             0.2340
# RandomForestClassifier                       0.9159             0.1429
# ExtraTreesClassifier                         0.9307             0.1415
# BaggingClassifier                            0.8875             0.1598
# GradientBoostingClassifier                   0.7652             0.2132
# AdaBoostClassifier                           0.7359             0.3774
# HistGradientBoostingClassifier               0.8889             0.1843
#
#                                 ss=nbrs2_o0.5 train  ss=nbrs2_o0.5 val  \
# Models
# LogisticRegression                           0.6853             0.3904
# LinearDiscriminantAnalysis                   0.7077             0.4215
# GaussianNB                                   0.7719             0.2717
# KNeighborsClassifier                         0.8889             0.2076
# SVC                                          0.7520             0.3427
# LinearSVC                                    0.6938             0.3982
# SGDClassifier                                0.6652             0.4144
# DecisionTreeClassifier                       0.8385             0.1562
# RandomForestClassifier                       0.8825             0.1717
# ExtraTreesClassifier                         0.8922             0.1087
# BaggingClassifier                            0.8480             0.1185
# GradientBoostingClassifier                   0.7698             0.2124
# AdaBoostClassifier                           0.7395             0.3427
# HistGradientBoostingClassifier               0.8613             0.1724
#
#                                 ss=nbrs3_o0.5 train  ss=nbrs3_o0.5 val  \
# Models
# LogisticRegression                           0.7018             0.3916
# LinearDiscriminantAnalysis                   0.7185             0.4082
# GaussianNB                                   0.7708             0.2714
# KNeighborsClassifier                         0.8739             0.2542
# SVC                                          0.7546             0.3503
# LinearSVC                                    0.7084             0.4006
# SGDClassifier                                0.6887             0.4276
# DecisionTreeClassifier                       0.8333             0.2066
# RandomForestClassifier                       0.8736             0.1502
# ExtraTreesClassifier                         0.8842             0.1496
# BaggingClassifier                            0.8455             0.0957
# GradientBoostingClassifier                   0.7751             0.2165
# AdaBoostClassifier                           0.7260             0.3785
# HistGradientBoostingClassifier               0.8614             0.1695
#
#                                 ss=nbrs4_o0.5 train  ss=nbrs4_o0.5 val  \
# Models
# LogisticRegression                           0.6869             0.4042
# LinearDiscriminantAnalysis                   0.7008             0.4290
# GaussianNB                                   0.7758             0.2751
# KNeighborsClassifier                         0.8669             0.2577
# SVC                                          0.7527             0.3526
# LinearSVC                                    0.6920             0.4006
# SGDClassifier                                0.6744             0.3881
# DecisionTreeClassifier                       0.8292             0.1101
# RandomForestClassifier                       0.8645             0.1471
# ExtraTreesClassifier                         0.8712             0.1446
# BaggingClassifier                            0.8378             0.1570
# GradientBoostingClassifier                   0.7566             0.2353
# AdaBoostClassifier                           0.7263             0.3618
# HistGradientBoostingClassifier               0.8357             0.1747
#
#                                 ss=nbrs5_o0.5 train  ss=nbrs5_o0.5 val  \
# Models
# LogisticRegression                           0.6909             0.4066
# LinearDiscriminantAnalysis                   0.7039             0.4303
# GaussianNB                                   0.7770             0.2774
# KNeighborsClassifier                         0.8657             0.2226
# SVC                                          0.7468             0.3642
# LinearSVC                                    0.6979             0.4054
# SGDClassifier                                0.6860             0.4084
# DecisionTreeClassifier                       0.8168             0.1953
# RandomForestClassifier                       0.8657             0.1452
# ExtraTreesClassifier                         0.8703             0.1282
# BaggingClassifier                            0.8421             0.1549
# GradientBoostingClassifier                   0.7763             0.2041
# AdaBoostClassifier                           0.7325             0.3947
# HistGradientBoostingClassifier               0.8550             0.1382
#
#                                 ss=nbrs6_o0.5 train  ss=nbrs6_o0.5 val  \
# Models
# LogisticRegression                           0.6895             0.4030
# LinearDiscriminantAnalysis                   0.7031             0.4203
# GaussianNB                                   0.7775             0.2766
# KNeighborsClassifier                         0.8551             0.2640
# SVC                                          0.7499             0.3571
# LinearSVC                                    0.6939             0.4006
# SGDClassifier                                0.6420             0.3804
# DecisionTreeClassifier                       0.8085             0.1562
# RandomForestClassifier                       0.8511             0.1464
# ExtraTreesClassifier                         0.8515             0.1606
# BaggingClassifier                            0.8286             0.1271
# GradientBoostingClassifier                   0.7641             0.2174
# AdaBoostClassifier                           0.7336             0.3215
# HistGradientBoostingClassifier               0.8507             0.1974
#
#                                 ss=nbrs7_o0.5 train  ss=nbrs7_o0.5 val
# Models
# LogisticRegression                           0.7118             0.4079
# LinearDiscriminantAnalysis                   0.7286             0.4265
# GaussianNB                                   0.7804             0.2716
# KNeighborsClassifier                         0.8577             0.2759
# SVC                                          0.7670             0.3454
# LinearSVC                                    0.7180             0.4006
# SGDClassifier                                0.6868             0.3968
# DecisionTreeClassifier                       0.8074             0.2321
# RandomForestClassifier                       0.8652             0.2083
# ExtraTreesClassifier                         0.8622             0.1923
# BaggingClassifier                            0.8306             0.1835
# GradientBoostingClassifier                   0.7936             0.2016
# AdaBoostClassifier                           0.7603             0.3526
# HistGradientBoostingClassifier               0.8523             0.1852

# %%
knbrs_results[knbrs_results.columns[14:]]
# Out:
#                                 ss=nbrs8_o0.5 train  ss=nbrs8_o0.5 val  \
# Models
# LogisticRegression                           0.7027             0.4066
# LinearDiscriminantAnalysis                   0.7250             0.4412
# GaussianNB                                   0.7785             0.2705
# KNeighborsClassifier                         0.8539             0.2448
# SVC                                          0.7579             0.3618
# LinearSVC                                    0.7151             0.4042
# SGDClassifier                                0.7094             0.4195
# DecisionTreeClassifier                       0.8048             0.1992
# RandomForestClassifier                       0.8505             0.2092
# ExtraTreesClassifier                         0.8560             0.1674
# BaggingClassifier                            0.8160             0.1843
# GradientBoostingClassifier                   0.8089             0.2469
# AdaBoostClassifier                           0.7712             0.3413
# HistGradientBoostingClassifier               0.8447             0.1896
#
#                                 ss=nbrs9_o0.5 train  ss=nbrs9_o0.5 val  \
# Models
# LogisticRegression                           0.7009             0.4000
# LinearDiscriminantAnalysis                   0.7181             0.4167
# GaussianNB                                   0.7735             0.2759
# KNeighborsClassifier                         0.8418             0.2560
# SVC                                          0.7601             0.3654
# LinearSVC                                    0.7089             0.3939
# SGDClassifier                                0.6672             0.3453
# DecisionTreeClassifier                       0.8145             0.2510
# RandomForestClassifier                       0.8480             0.1695
# ExtraTreesClassifier                         0.8574             0.1496
# BaggingClassifier                            0.8315             0.2045
# GradientBoostingClassifier                   0.7883             0.2311
# AdaBoostClassifier                           0.7598             0.3547
# HistGradientBoostingClassifier               0.8444             0.1591
#
#                                 ss=nbrs10_o0.5 train  ss=nbrs10_o0.5 val  \
# Models
# LogisticRegression                            0.6876              0.4066
# LinearDiscriminantAnalysis                    0.7063              0.4179
# GaussianNB                                    0.7756              0.2712
# KNeighborsClassifier                          0.8375              0.2827
# SVC                                           0.7431              0.3729
# LinearSVC                                     0.6971              0.4042
# SGDClassifier                                 0.6117              0.4136
# DecisionTreeClassifier                        0.7945              0.1296
# RandomForestClassifier                        0.8360              0.1717
# ExtraTreesClassifier                          0.8456              0.1899
# BaggingClassifier                             0.8143              0.1794
# GradientBoostingClassifier                    0.7984              0.1899
# AdaBoostClassifier                            0.7684              0.2768
# HistGradientBoostingClassifier                0.8402              0.1651
#
#                                 ss=nbrs11_o0.5 train  ss=nbrs11_o0.5 val  \
# Models
# LogisticRegression                            0.6852              0.4054
# LinearDiscriminantAnalysis                    0.7029              0.4277
# GaussianNB                                    0.7764              0.2755
# KNeighborsClassifier                          0.8383              0.2737
# SVC                                           0.7609              0.3704
# LinearSVC                                     0.6941              0.4066
# SGDClassifier                                 0.6721              0.4250
# DecisionTreeClassifier                        0.8020              0.1496
# RandomForestClassifier                        0.8448              0.1923
# ExtraTreesClassifier                          0.8458              0.1709
# BaggingClassifier                             0.8136              0.1818
# GradientBoostingClassifier                    0.7987              0.1762
# AdaBoostClassifier                            0.7714              0.3167
# HistGradientBoostingClassifier                0.8486              0.1435
#
#                                 ss=nbrs12_o0.5 train  ss=nbrs12_o0.5 val  \
# Models
# LogisticRegression                            0.6897              0.4091
# LinearDiscriminantAnalysis                    0.7104              0.4425
# GaussianNB                                    0.7779              0.2770
# KNeighborsClassifier                          0.8317              0.2321
# SVC                                           0.7508              0.3497
# LinearSVC                                     0.7007              0.4066
# SGDClassifier                                 0.6903              0.4006
# DecisionTreeClassifier                        0.7900              0.2140
# RandomForestClassifier                        0.8372              0.1739
# ExtraTreesClassifier                          0.8422              0.1293
# BaggingClassifier                             0.8069              0.1136
# GradientBoostingClassifier                    0.8050              0.2371
# AdaBoostClassifier                            0.7773              0.3265
# HistGradientBoostingClassifier                0.8444              0.1422
#
#                                 ss=nbrs13_o0.5 train  ss=nbrs13_o0.5 val
# Models
# LogisticRegression                            0.6941              0.4180
# LinearDiscriminantAnalysis                    0.7153              0.4421
# GaussianNB                                    0.7745              0.2732
# KNeighborsClassifier                          0.8292              0.2660
# SVC                                           0.7287              0.3148
# LinearSVC                                     0.7020              0.4154
# SGDClassifier                                 0.6679              0.3972
# DecisionTreeClassifier                        0.7909              0.1446
# RandomForestClassifier                        0.8410              0.1535
# ExtraTreesClassifier                          0.8425              0.1288
# BaggingClassifier                             0.8050              0.2193
# GradientBoostingClassifier                    0.8095              0.1628
# AdaBoostClassifier                            0.7739              0.3125
# HistGradientBoostingClassifier                0.8427              0.1250

# %%
sample_vs = [0.7]
knbrs_results = pd.DataFrame()
print('Train vs validation results for SVMSMOTE technique.')
for kn_no in range(1, 14):
    print('k_neighbors:', kn_no)
    oversample_tq = SVMSMOTE(sampling_strategy=oversample_v, k_neighbors=kn_no, random_state=24)
    X_o, y_o = oversample_tq.fit_resample(X_train, y_train)
    sample_v = f'nbrs{kn_no}_o{sample_vs[0]}'
    results_df = get_models_scores_vs_val_for_sampling(models, X_o, y_o, splitter, X_val, y_val, sample_v)
    knbrs_results = pd.concat([knbrs_results, results_df], axis=1)
# Out:
# Train vs validation results for SVMSMOTE technique.
# k_neighbors: 1
# k_neighbors: 2
# k_neighbors: 3
# k_neighbors: 4
# k_neighbors: 5
# k_neighbors: 6
# k_neighbors: 7
# k_neighbors: 8
# k_neighbors: 9
# k_neighbors: 10
# k_neighbors: 11
# k_neighbors: 12
# k_neighbors: 13

# %%
knbrs_results[knbrs_results.columns[:14]]
# Out:
#                                 ss=nbrs1_o0.7 train  ss=nbrs1_o0.7 val  \
# Models
# LogisticRegression                           0.6572             0.3623
# LinearDiscriminantAnalysis                   0.6896             0.3873
# GaussianNB                                   0.7271             0.2878
# KNeighborsClassifier                         0.9164             0.2814
# SVC                                          0.7674             0.3612
# LinearSVC                                    0.6646             0.3777
# SGDClassifier                                0.6452             0.3987
# DecisionTreeClassifier                       0.8578             0.0746
# RandomForestClassifier                       0.9082             0.1309
# ExtraTreesClassifier                         0.9229             0.1295
# BaggingClassifier                            0.8805             0.1523
# GradientBoostingClassifier                   0.7826             0.1907
# AdaBoostClassifier                           0.7419             0.2652
# HistGradientBoostingClassifier               0.8844             0.1515
#
#                                 ss=nbrs2_o0.7 train  ss=nbrs2_o0.7 val  \
# Models
# LogisticRegression                           0.6655             0.4225
# LinearDiscriminantAnalysis                   0.7027             0.3819
# GaussianNB                                   0.7302             0.2911
# KNeighborsClassifier                         0.8906             0.2675
# SVC                                          0.7643             0.3791
# LinearSVC                                    0.6782             0.3806
# SGDClassifier                                0.6614             0.3750
# DecisionTreeClassifier                       0.8367             0.1826
# RandomForestClassifier                       0.8855             0.1970
# ExtraTreesClassifier                         0.8982             0.1724
# BaggingClassifier                            0.8600             0.1500
# GradientBoostingClassifier                   0.7859             0.2027
# AdaBoostClassifier                           0.7251             0.3261
# HistGradientBoostingClassifier               0.8691             0.1508
#
#                                 ss=nbrs3_o0.7 train  ss=nbrs3_o0.7 val  \
# Models
# LogisticRegression                           0.6620             0.4064
# LinearDiscriminantAnalysis                   0.7038             0.3833
# GaussianNB                                   0.7300             0.2810
# KNeighborsClassifier                         0.8827             0.2664
# SVC                                          0.7753             0.3731
# LinearSVC                                    0.6745             0.3979
# SGDClassifier                                0.6868             0.3869
# DecisionTreeClassifier                       0.8163             0.1982
# RandomForestClassifier                       0.8752             0.1707
# ExtraTreesClassifier                         0.8838             0.1435
# BaggingClassifier                            0.8401             0.1302
# GradientBoostingClassifier                   0.7745             0.2370
# AdaBoostClassifier                           0.7397             0.3396
# HistGradientBoostingClassifier               0.8556             0.1471
#
#                                 ss=nbrs4_o0.7 train  ss=nbrs4_o0.7 val  \
# Models
# LogisticRegression                           0.6714             0.4035
# LinearDiscriminantAnalysis                   0.7105             0.3767
# GaussianNB                                   0.7306             0.2838
# KNeighborsClassifier                         0.8564             0.2621
# SVC                                          0.7832             0.3802
# LinearSVC                                    0.6817             0.3979
# SGDClassifier                                0.6461             0.4019
# DecisionTreeClassifier                       0.7932             0.2381
# RandomForestClassifier                       0.8508             0.1683
# ExtraTreesClassifier                         0.8656             0.1422
# BaggingClassifier                            0.8200             0.1691
# GradientBoostingClassifier                   0.7864             0.2609
# AdaBoostClassifier                           0.7200             0.2734
# HistGradientBoostingClassifier               0.8415             0.1914
#
#                                 ss=nbrs5_o0.7 train  ss=nbrs5_o0.7 val  \
# Models
# LogisticRegression                           0.6712             0.3763
# LinearDiscriminantAnalysis                   0.6991             0.3966
# GaussianNB                                   0.7265             0.2865
# KNeighborsClassifier                         0.8324             0.2419
# SVC                                          0.7552             0.3612
# LinearSVC                                    0.6772             0.3873
# SGDClassifier                                0.6615             0.3810
# DecisionTreeClassifier                       0.7922             0.1674
# RandomForestClassifier                       0.8411             0.1422
# ExtraTreesClassifier                         0.8491             0.1422
# BaggingClassifier                            0.8065             0.1382
# GradientBoostingClassifier                   0.7510             0.2347
# AdaBoostClassifier                           0.7056             0.2996
# HistGradientBoostingClassifier               0.8289             0.1620
#
#                                 ss=nbrs6_o0.7 train  ss=nbrs6_o0.7 val  \
# Models
# LogisticRegression                           0.6571             0.3636
# LinearDiscriminantAnalysis                   0.6997             0.3915
# GaussianNB                                   0.7290             0.2806
# KNeighborsClassifier                         0.8442             0.2569
# SVC                                          0.7534             0.3053
# LinearSVC                                    0.6753             0.3710
# SGDClassifier                                0.6882             0.4059
# DecisionTreeClassifier                       0.8034             0.3057
# RandomForestClassifier                       0.8343             0.1208
# ExtraTreesClassifier                         0.8417             0.1860
# BaggingClassifier                            0.8083             0.1220
# GradientBoostingClassifier                   0.7773             0.1843
# AdaBoostClassifier                           0.7242             0.2918
# HistGradientBoostingClassifier               0.8334             0.1435
#
#                                 ss=nbrs7_o0.7 train  ss=nbrs7_o0.7 val
# Models
# LogisticRegression                           0.6707             0.3887
# LinearDiscriminantAnalysis                   0.7007             0.3767
# GaussianNB                                   0.7299             0.2859
# KNeighborsClassifier                         0.8284             0.2600
# SVC                                          0.7683             0.3745
# LinearSVC                                    0.6808             0.3659
# SGDClassifier                                0.6167             0.3906
# DecisionTreeClassifier                       0.7784             0.2033
# RandomForestClassifier                       0.8445             0.2074
# ExtraTreesClassifier                         0.8472             0.1835
# BaggingClassifier                            0.8037             0.1157
# GradientBoostingClassifier                   0.7862             0.2370
# AdaBoostClassifier                           0.7250             0.3042
# HistGradientBoostingClassifier               0.8281             0.1493

# %%
knbrs_results[knbrs_results.columns[14:]]
# Out:
#                                 ss=nbrs8_o0.7 train  ss=nbrs8_o0.7 val  \
# Models
# LogisticRegression                           0.6549             0.3915
# LinearDiscriminantAnalysis                   0.6836             0.3898
# GaussianNB                                   0.7314             0.2863
# KNeighborsClassifier                         0.8338             0.2918
# SVC                                          0.7412             0.3774
# LinearSVC                                    0.6608             0.3671
# SGDClassifier                                0.6522             0.0781
# DecisionTreeClassifier                       0.7814             0.1471
# RandomForestClassifier                       0.8289             0.2294
# ExtraTreesClassifier                         0.8393             0.1613
# BaggingClassifier                            0.7958             0.0971
# GradientBoostingClassifier                   0.7748             0.2113
# AdaBoostClassifier                           0.7102             0.2737
# HistGradientBoostingClassifier               0.8301             0.1691
#
#                                 ss=nbrs9_o0.7 train  ss=nbrs9_o0.7 val  \
# Models
# LogisticRegression                           0.6788             0.3804
# LinearDiscriminantAnalysis                   0.7112             0.3819
# GaussianNB                                   0.7338             0.2889
# KNeighborsClassifier                         0.8187             0.2632
# SVC                                          0.7806             0.3759
# LinearSVC                                    0.6896             0.3697
# SGDClassifier                                0.6862             0.2830
# DecisionTreeClassifier                       0.7857             0.2232
# RandomForestClassifier                       0.8436             0.1860
# ExtraTreesClassifier                         0.8476             0.1598
# BaggingClassifier                            0.8064             0.1471
# GradientBoostingClassifier                   0.7867             0.2045
# AdaBoostClassifier                           0.7371             0.3269
# HistGradientBoostingClassifier               0.8379             0.1263
#
#                                 ss=nbrs10_o0.7 train  ss=nbrs10_o0.7 val  \
# Models
# LogisticRegression                            0.6715              0.3777
# LinearDiscriminantAnalysis                    0.6995              0.3966
# GaussianNB                                    0.7322              0.2863
# KNeighborsClassifier                          0.8119              0.2653
# SVC                                           0.7438              0.3282
# LinearSVC                                     0.6790              0.3873
# SGDClassifier                                 0.6642              0.2392
# DecisionTreeClassifier                        0.7793              0.2183
# RandomForestClassifier                        0.8266              0.1643
# ExtraTreesClassifier                          0.8239              0.1843
# BaggingClassifier                             0.7910              0.1932
# GradientBoostingClassifier                    0.7758              0.1896
# AdaBoostClassifier                            0.7455              0.2963
# HistGradientBoostingClassifier                0.8187              0.1683
#
#                                 ss=nbrs11_o0.7 train  ss=nbrs11_o0.7 val  \
# Models
# LogisticRegression                            0.6821              0.3791
# LinearDiscriminantAnalysis                    0.7111              0.4049
# GaussianNB                                    0.7333              0.2880
# KNeighborsClassifier                          0.8044              0.2686
# SVC                                           0.7498              0.3414
# LinearSVC                                     0.6896              0.3929
# SGDClassifier                                 0.6751              0.4030
# DecisionTreeClassifier                        0.7743              0.1681
# RandomForestClassifier                        0.8219              0.1190
# ExtraTreesClassifier                          0.8285              0.1376
# BaggingClassifier                             0.7849              0.1667
# GradientBoostingClassifier                    0.7959              0.1896
# AdaBoostClassifier                            0.7293              0.3373
# HistGradientBoostingClassifier                0.8288              0.1295
#
#                                 ss=nbrs12_o0.7 train  ss=nbrs12_o0.7 val  \
# Models
# LogisticRegression                            0.6714              0.3943
# LinearDiscriminantAnalysis                    0.7028              0.3833
# GaussianNB                                    0.7331              0.2859
# KNeighborsClassifier                          0.8111              0.2449
# SVC                                           0.7448              0.3360
# LinearSVC                                     0.6802              0.3833
# SGDClassifier                                 0.6632              0.2672
# DecisionTreeClassifier                        0.7693              0.2500
# RandomForestClassifier                        0.8231              0.1860
# ExtraTreesClassifier                          0.8291              0.1628
# BaggingClassifier                             0.7853              0.1000
# GradientBoostingClassifier                    0.7783              0.1759
# AdaBoostClassifier                            0.7361              0.3422
# HistGradientBoostingClassifier                0.8257              0.1485
#
#                                 ss=nbrs13_o0.7 train  ss=nbrs13_o0.7 val
# Models
# LogisticRegression                            0.6628              0.3833
# LinearDiscriminantAnalysis                    0.6940              0.3925
# GaussianNB                                    0.7318              0.2863
# KNeighborsClassifier                          0.7951              0.2282
# SVC                                           0.7554              0.3422
# LinearSVC                                     0.6716              0.3952
# SGDClassifier                                 0.6918              0.4040
# DecisionTreeClassifier                        0.7691              0.1245
# RandomForestClassifier                        0.8161              0.2143
# ExtraTreesClassifier                          0.8248              0.1843
# BaggingClassifier                             0.7867              0.1485
# GradientBoostingClassifier                    0.7875              0.1659
# AdaBoostClassifier                            0.7326              0.3333
# HistGradientBoostingClassifier                0.8245              0.1471

# %% [markdown]
# Looks similar to ADASYN case.

# %% [raw]
# Let's focus on ADASYN + RandomUnderSampler and top 5 performing models (algotythms), i.e.:
#     LogisticRegression
#     LinearDiscriminantAnalysis
#     LinearSVC
#     SGDClassifier
#     AdaBoostClassifier
#
# To beat:
# Model						train	val
# LogisticRegression  		0.7609	0.3979
# LinearDiscriminantAnalysis	0.7693	0.4134
# LinearSVC					0.7676	0.4145
# SGDClassifier				0.7621	0.4282
# AdaBoostClassifier			0.7933	0.3388
#
# It is time for some hyperparameters searching. The idea is to check relatively quickly how the models responds on the hyperparameters adjustment.

# %% [markdown]
# Before hyperparameter tuning let's check the scores for dummy classifier. That can be treat as a benchmark.

# %%
from sklearn.dummy import DummyClassifier

# %%
dc = DummyClassifier(strategy='constant', constant=1, random_state=24)
dc.fit(X_train, y_train)
dc_y_pred = dc.predict(X_train)

# %%
fbeta_score(y_train, dc_y_pred, beta=2)
# Out:
# 0.2035330261136713

# %% [raw]
# 0.1569 DummyClassifier(strategy='uniform', random_state=24)
# 0.0624 DummyClassifier(strategy='stratified', random_state=24)
# 0.2035 DummyClassifier(strategy='constant', constant=1, random_state=24)
# 0.0    DummyClassifier(strategy='constant', constant=0, random_state=24)

# %% [markdown]
# In case the model predicts only 1 the f2_score will be 0.2035.

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint

# %%
oversample_v = 0.5
undersample_v = 0.7
oversample_tq = ADASYN(sampling_strategy=oversample_v, random_state=24)
undersample_tq = RandomUnderSampler(sampling_strategy=undersample_v, random_state=24)
resample_pipeline = imPipeline([('oversampling', oversample_tq), ('undersampling', undersample_tq)])
X_ou, y_ou = resample_pipeline.fit_resample(X_train, y_train)

# %% [markdown]
# Logistic Regression

# %%
lr_rsc = LogisticRegression(random_state=24)
distributions = dict(C=uniform(loc=0, scale=4), 
                     penalty=['l2'], 
                     solver=['newton-cg', 'lbfgs', 'sag', 'saga', 'liblinear'], 
                     max_iter=randint(200, 1500),
#                      fit_intercept=[True, False],
#                      class_weight=[None, 'balanced']
                    ) #'saga' can get l1, rest only l2 
rscv = RandomizedSearchCV(lr_rsc, distributions, cv=splitter, scoring=f2_scorer, random_state=24, n_iter=2877)

# %%
# %%time
lr_search = rscv.fit(X_ou, y_ou)
# Out:
# Wall time: 50min 30s

# %%
lr_search.best_params_
# Out:
# {'C': 0.008632525096375243,
#  'max_iter': 973,
#  'penalty': 'l2',
#  'solver': 'liblinear'}

# %%
# lr_tng = LogisticRegression(C=0.008632525096375243, max_iter=361, penalty='l2', solver='newton-cg', 
#                             class_weight='balanced', random_state=24)
# lr_tng = LogisticRegression(C=0.05097413466747014, max_iter=604, penalty='l2', solver='sag', random_state=24)
lr_tng = LogisticRegression(C=0.008632525096375243, max_iter=973, penalty='l2', solver='liblinear', random_state=24)

# %%
cross_val_scores(lr_tng, X_ou, y_ou, splitter)
# Out:
# 0.7802527931152647

# %%
get_val_pred_score(lr_tng, X_ou, y_ou, X_val, y_val)
# Out:
# 0.42635658914728686

# %% [raw]
# Achieved results for LogisticRegression are 0.78025/0.4264 for train/val dataset, respectively.
# The validations is better by 7.2% (before 0.3979).

# %% [markdown]
# Linear Discriminant Analysis

# %%
lda_rsc = LinearDiscriminantAnalysis()
distributions = dict(solver=['svd', 'lsqr', 'eigen'], 
#                      shrinkage=[None, 'auto']+list(np.arange(0, 1, 0.01)),
                     shrinkage=np.arange(0, 1, 0.01),
                     tol=[1/10**x for x in range(1, 8)]
                    )
rscv = RandomizedSearchCV(lda_rsc, distributions, cv=splitter, scoring=f2_scorer, random_state=24, n_iter=1000)

# %%
# %%time
lda_search = rscv.fit(X_ou, y_ou)
# Out:
# Wall time: 2min 20s

# %%
lda_search.best_params_
# Out:
# {'tol': 0.0001, 'solver': 'lsqr', 'shrinkage': 0.6900000000000001}

# %%
lda_tng = LinearDiscriminantAnalysis(tol=1.0e-4, solver='lsqr', shrinkage=0.69)

# %%
cross_val_scores(lda_tng, X_ou, y_ou, splitter)
# Out:
# 0.7974659544885918

# %%
get_val_pred_score(lda_tng, X_ou, y_ou, X_val, y_val)
# Out:
# 0.41463414634146345

# %% [raw]
# 0.4145 LinearDiscriminantAnalysis(tol=1.0e-4, solver='lsqr', shrinkage='auto')
# 0.4146 LinearDiscriminantAnalysis(tol=1.0e-5, solver='eigen', shrinkage=0.69)

# %% [markdown]
# Achieved results for LinearDiscriminantAnalysis are 0.7975/0.4146 for train/val dataset, respectively.
# The validations is better by 0.3% (before 0.4134).

# %% [markdown]
# Linear SVC

# %%
lsvc_rsc = LinearSVC(random_state=24)
distributions = dict(C=uniform(loc=0, scale=4), 
                     penalty=['l1', 'l2'],
                     loss=['hinge', 'squared_hinge'],
#                      dual=[True, False], if n_samples > n_features then dual should be False
                     dual=[False],
                     tol=[1/10**x for x in range(1, 8)],
                     max_iter=randint(1000, 12000),
                     fit_intercept=[True, False]
#                      class_weight=[None, 'balanced']
                    ) 
rscv = RandomizedSearchCV(lsvc_rsc, distributions, cv=splitter, scoring=f2_scorer, random_state=24, n_iter=8888, error_score=np.NINF)

# %%
# %%time
lsvc_search = rscv.fit(X_ou, y_ou)

# %%
lsvc_search.best_params_
# Out:
# {'C': 0.005750984762251665,
#  'dual': False,
#  'fit_intercept': True,
#  'loss': 'squared_hinge',
#  'max_iter': 3235,
#  'penalty': 'l1',
#  'tol': 1e-06}

# %%
# lsvc_tng = LinearSVC(C=0.01619532623902531, dual=False, fit_intercept=False, loss='squared_hinge', penalty='l1', max_iter=6559,
#                     tol=1.0e-4, random_state=24)
lsvc_tng = LinearSVC(C=0.005750984762251665, dual=False, fit_intercept=True, loss='squared_hinge', penalty='l1', max_iter=3235,
                    tol=1.0e-6, random_state=24)

# %%
cross_val_scores(lsvc_tng, X_ou, y_ou, splitter)
# Out:
# 0.783315184222561

# %%
get_val_pred_score(lsvc_tng, X_ou, y_ou, X_val, y_val)
# Out:
# 0.414572864321608

# %% [raw]
# 0.3953 LinearSVC(C=0.19314819962114216, class_weight='balanced', dual=True,
#         fit_intercept=True, loss='hinge', tol=1.0e-3, max_iter=2243, penalty='l2')
# 0.3953 LinearSVC(C=0.0910654446599879, class_weight='balanced', dual=False,
#                      fit_intercept=True, loss='squared_hinge', tol=1.0e-1, max_iter=3015, penalty='l1')
# 0.3991 LinearSVC(C=2.7001793835489756, class_weight='balanced', dual=False,
#                      fit_intercept=True, loss='squared_hinge', tol=1.0e-1, max_iter=5539, penalty='l1')
# 0.4060 LinearSVC(C=0.06641161764975756, class_weight='balanced', dual=False,
#                      fit_intercept=False, loss='squared_hinge', tol=1.0e-2, max_iter=2640, penalty='l1')
# 0.4167 LinearSVC(C=0.0776546948325038, dual=False, fit_intercept=True, loss='squared_hinge', penalty='l1', max_iter=8512,
#                     tol=1.0e-5)
# 0.4188 LinearSVC(C=0.01619532623902531, dual=False, fit_intercept=False, loss='squared_hinge', penalty='l1', max_iter=6559,
#                     tol=1.0e-4)
# 0.4146 LinearSVC(C=0.005750984762251665, dual=False, fit_intercept=True, loss='squared_hinge', penalty='l1', max_iter=3235,
#                     tol=1.0e-6)

# %% [markdown]
# Achieved results for LinearSVC are 0.7791/0.4188 for train/val dataset, respectively.
# The validations is better by 1% (before 0.4145).

# %% [markdown]
# SGDClassifier

# %%
sgdc_rsc = SGDClassifier(random_state=24)
distributions = dict( 
#                      penalty=['l1', 'elasticnet'], 
                     penalty=['elasticnet'],
#                      loss=['squared_hinge', 'perceptron'],
                     alpha=np.arange(0.00001, 0.001, 0.0001),
                     l1_ratio=np.arange(0.05, 1, 0.05),
#                      dual=[True, False], # if n_samples > n_features then dual should be False
#                      tol=np.arange(0.00001, 0.001, 0.0001),
#                      max_iter=randint(750, 1500),
                     learning_rate=['optimal', 'invscaling', 'adaptive'],
                     eta0=np.arange(0.001, 2, 0.001),
                     power_t=[0.1, 0.25, 0.5, 0.75, 1, 2],
#                      fit_intercept=[True, False],
#                      class_weight=[None, 'balanced'],
#                      early_stopping=[True, False],
#                      validation_fraction=[0.1, 0.2, 0.3],
#                      n_iter_no_change=[3, 5, 10, 20],
                     random_state=[24]
                    ) 
rscv = RandomizedSearchCV(sgdc_rsc, distributions, cv=splitter, scoring=f2_scorer, random_state=24, n_iter=9876, error_score=np.NINF, n_jobs=-1)

# %%
# %%time
sgdc_search = rscv.fit(X_ou, y_ou)
# Out:
# Wall time: 1.99 s

# %%
# sgdc_search.best_params_

# %%
def get_params_from_dict(dict_params):
    for key, value in dict_params.items():
        if type(value) == str:
            print(f"{key}='{value}',")
        else:
            print(f'{key}={value},')

# %%
get_params_from_dict(sgdc_search.best_params_)
# Out:
# tol=0.00041000000000000005,
# random_state=24,
# penalty='elasticnet',
# learning_rate='optimal',
# l1_ratio=0.1,
# alpha=0.00051,

# %%
# sgdc_tng = SGDClassifier(alpha=0.26191, class_weight='balanced', early_stopping=True, epsilon=0.05, fit_intercept=True,
#                         l1_ratio=0.65, loss='epsilon_insensitive', max_iter=1797, penalty='l1', tol=1.0e-6)
# sgdc_tng = SGDClassifier(alpha=0.24441, early_stopping=True, epsilon=0.05, l1_ratio=0.1, penalty='elasticnet', random_state=24)
# sgdc_tng = SGDClassifier(alpha=0.0049, early_stopping=False, penalty='l1', loss='perceptron', 
#                          l1_ratio=0.15, tol=0.25, random_state=24)
# sgdc_tng = SGDClassifier(alpha=0.0005, tol=0.0001, penalty='elasticnet', l1_ratio=0.05, random_state=24)
sgdc_tng = SGDClassifier(alpha=0.0004, penalty='elasticnet', l1_ratio=0.05, random_state=24)
# sgdc_tng = SGDClassifier(alpha=0.0004, penalty='elasticnet', l1_ratio=0.05, random_state=24, learning_rate='invscaling', eta0=2, power_t=0.5)

# %%
cross_val_scores(sgdc_tng, X_ou, y_ou, splitter)
# Out:
# 0.773184552660715

# %%
get_val_pred_score(sgdc_tng, X_ou, y_ou, X_val, y_val)
# Out:
# 0.43814432989690727

# %% [raw]
# 0.4315 SGDClassifier(alpha=0.001, penalty='l1', random_state=24)
# 0.4326 SGDClassifier(alpha=0.001, random_state=24)
# 0.4381 SGDClassifier(alpha=0.0004, penalty='elasticnet', l1_ratio=0.05, random_state=24)
# 0.4326 SGDClassifier(alpha=0.0005, tol=0.0001, penalty='elasticnet', l1_ratio=0.05, random_state=24)
# 0.4365 SGDClassifier(alpha=0.0004, penalty='elasticnet', l1_ratio=0.05, random_state=24, learning_rate='constant', eta0=0.01)

# %% [markdown]
# 0.4282

# %% [markdown]
# Achieved results for SGDClassifier are 0.7732/0.4381 for train/val dataset, respectively.
# The validations is better by 2.3% (before 0.4282).

# %% [markdown]
# AdaBoost Classifier

# %% [markdown]
# #### The estimators supported by AdaBoost Classifier i.a. are:
#         BernoulliNB,
#         DecisionTreeClassifier,
#         ExtraTreeClassifier,
#         ExtraTreesClassifier,
#         MultinomialNB,
#         NuSVC,
#         Perceptron,
#         RandomForestClassifier,
#         RidgeClassifierCV,
#         SGDClassifier,
#         SVC
#
#     Let's choose a couple and check the results.
#     Ada Boost Classifier by default uses the DecisionTreeClassifier initialized with max_depth=1, so the good idea is to check other tree based algorithms with the same parameter. Based on that the RandomizedSearchCV will be performed.
#     DecisionTreeClassifier, ExtraTreesClassifier, ExtraTreeClassifier and RandomForestClassifier.

# %%
from sklearn.tree import ExtraTreeClassifier

# %%
abc_tng = AdaBoostClassifier(base_estimator=RandomForestClassifier(max_depth=1), random_state=24)
cross_val_scores(abc_tng, X_ou, y_ou, splitter)

# %%
get_val_pred_score(abc_tng, X_ou, y_ou, X_val, y_val)

# %% [raw]
# 0.7933/0.3388 DecisionTreeClassifier(max_depth=1)
# 0.7739/0.3774 ExtraTreeClassifier(max_depth=1)
# 0.7739/0.3774 ExtraTreesClassifier(max_depth=1)
# 0.7883/0.3419 RandomForestClassifier(max_depth=1)

# %% [markdown]
# Two best are ExtraTreeClassifier and ExtraTreesClassifier.<br>
# The Ada Boost was designed to work with weak learners so let's focus on the single Tree instead of ensembled algorithm.<br>

# %%
abc_rsc = AdaBoostClassifier(random_state=24)
distributions = dict(
#                      base_estimator=[DecisionTreeClassifier(), ExtraTreesClassifier(), ExtraTreeClassifier(), RandomForestClassifier()],
                     base_estimator=[ExtraTreeClassifier(random_state=24)],
#                      base_estimator__max_depth=[x for x in range(1, 11, 2)],
                     base_estimator__max_depth=[1, 2, 3],
                     base_estimator__min_samples_leaf=[x for x in range(1, 20)],
                     n_estimators=[x for x in range(25, 2001, 25)],
                     learning_rate=np.arange(0.05, 1, 0.05),
                     algorithm=['SAMME.R', 'SAMME']
                    ) 
rscv = RandomizedSearchCV(abc_rsc, distributions, cv=splitter, scoring=f2_scorer, random_state=24, n_iter=300, error_score=np.NINF)

# %%
# %%time
abc_search = rscv.fit(X_ou, y_ou)
# Out:
# Wall time: 5h 15min 57s

# %%
get_params_from_dict(abc_search.best_params_)
# Out:
# algorithm='SAMME.R',
# base_estimator=ExtraTreeClassifier(max_depth=7, min_samples_leaf=10, random_state=24),
# base_estimator__max_depth=7,
# base_estimator__min_samples_leaf=10,
# learning_rate=0.05,
# n_estimators=915,

# %%
# abc_tng = AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=1), n_estimators=133, learning_rate=1.85, algorithm='SAMME', random_state=24)
# abc_tng = AdaBoostClassifier(base_estimator=RandomForestClassifier(max_depth=1), random_state=24)
# abc_tng = AdaBoostClassifier(random_state=24)
abc_tng = AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=2, min_samples_leaf=10, random_state=24),
                             learning_rate=0.05,
                             n_estimators=900,
                             random_state=24)

# %%
cross_val_scores(abc_tng, X_ou, y_ou, splitter)
# Out:
# 0.8111404412281389

# %%
get_val_pred_score(abc_tng, X_ou, y_ou, X_val, y_val)
# Out:
# 0.41033434650455936

# %% [markdown]
# Some notes:<br>
# if the max_depth is high the model become overfitted<br>
# learning_rate learning rate over 1 decrease the score<br>

# %% [markdown]
# 0.3963 AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=2, min_samples_leaf=1, random_state=24),
#                              learning_rate=0.05, n_estimators=915, random_state=24)<br>
# 0.3887 AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=1, min_samples_leaf=1, random_state=24),
#                              learning_rate=1, n_estimators=90, random_state=24)<br>
# 0.3939 AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=24),
#                              learning_rate=0.05, n_estimators=900, random_state=24)<br>
# 0.4103 AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=2, min_samples_leaf=10, random_state=24),
#                              learning_rate=0.05, n_estimators=900, random_state=24)<br>

# %% [markdown]
# Achieved results for AdaBoostClassifier(ExtraTreeClassifier) are 0.8111/0.4103 for train/val dataset, respectively.<br>
# The validations is better by 8.7% (before 0.3774).<br>

# %% [markdown]
# Let's take a look on one of the outlier/anomaly detection algorithm.

# %%
OneClass SVM

# %%
from sklearn.svm import OneClassSVM

# %%
X_train_out, X_test_out, y_train_out, y_test_out = train_test_split(X_train, y_train, test_size=0.5, random_state=24, stratify=y_train)

# %%
X_train_out = X_train_out[y_train_out==0]

# the predict output is -1 and 1 instead of 1 and 0, respectively
y_test_out[y_test_out == 1] = -1
y_test_out[y_test_out == 0] = 1

# %%
# oc_svm = OneClassSVM(kernel='sigmoid', gamma='scale', coef0=0.5) #‘rbf’, ‘sigmoid’ # gamma{‘scale’, ‘auto’} coef0
oc_svm = OneClassSVM(kernel='rbf', gamma='scale', tol=2, nu=0.37, shrinking=False)
oc_svm.fit(X_train_out)

y_pred = oc_svm.predict(X_test_out)

f2_score = fbeta_score(y_test_out, y_pred, pos_label=-1, beta=2)
f2_score
# Out:
# 0.3509719222462203

# %% [markdown]
# Let's test the model

# %%
X_val_out = X_val.copy()
y_val_out = y_val.copy()

# %%
y_val_out[y_val_out == 1] = -1
y_val_out[y_val_out == 0] = 1

# %%
# oc_svm = OneClassSVM(kernel='rbf', gamma='scale', tol=2, nu=0.37, shrinking=False)
oc_svm = OneClassSVM()
oc_svm.fit(X_train_out)

y_pred = oc_svm.predict(X_val_out)

f2_score = fbeta_score(y_val_out, y_pred, pos_label=-1, beta=2)
f2_score
# Out:
# 0.28735632183908044

# %% [markdown]
# 0.3109 OneClassSVM(kernel='rbf', gamma='scale', tol=2)<br>
# 0.3510 OneClassSVM(kernel='rbf', gamma='scale', tol=2, nu=0.37)<br>

# %% [markdown]
# Achieved result for OneClassSVM is 0.3510 for test (new created for OCSVM) dataset, respectively.<br>
# The validations is better by 13.5% (before 0.3093).<br>
# For the validation dataset, which can be treated as test dataset (not used for evaluation and tuning) it is:<br>
# &emsp;0.2874 for initial model<br>
# &emsp;0.3298 for tuned model<br>
# &emsp;That gives 14.8% of improvment.<br>

# %% [markdown]
# #### Let's look at the results of RandomizedSearchCV.
#
#     Model                      gain    score
#     LogisticRegression         7.2%    0.4264
#     LinearDiscriminantAnalysis 0.3%    0.4146
#     LinearSVC                  1%      0.4188
#     SGDClassifier              2.3%    0.4381
#     AdaBoostClassifier         8.7%    0.4103
#     OneClassSVM                13.5%   0.3510
#
#     Let's focus on the three algorithms with best score (1) and best improvement (2).
#     SGDClassifier              2.3%    0.4381
#     AdaBoostClassifier         8.7%    0.4103
#     OneClassSVM                13.5%   0.3510
#
#     Features for further GridSearchCV searching:
#     SGDClassifier
#         alpha (low values e.g. 0.0004),
#         penalty,
#         l1_ratio (low values e.g. 0.05),
#         random_state=24,
#         learning_rate,
#         eta0 (values [0.01, 2])
#
#     AdaBoostClassifier
#         base_estimator ExtraTreeClassifier
#             max_depth values [1, 3],
#             min_samples_leaf [8, 12]
#             random_state=24,
#         learning_rate values [0.01, 1],
#         n_estimators [800, 1100] step 25,
#         random_state=24
#
#     OneClassSVM (kernel='rbf', gamma='scale', tol=2, nu=0.37)
#         kernel,
#         gamma,
#         tol values [0.1, 3] step 0.1,
#         nu values [0.2, 0.6] step 0.01

# %% [markdown]
# GridSearchCV

# %% [markdown]
# SGDClassifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = dict( 
                     penalty=['l2', 'l1', 'elasticnet'], 
                     alpha=np.arange(0.0001, 0.001, 0.0005),
                     l1_ratio=np.arange(0.05, 1, 0.05),
                     learning_rate=['optimal', 'invscaling', 'adaptive'],
                     eta0=np.arange(0.01, 2, 0.02),
                     random_state=[24]
                    )

# %%
sgdc_clf = SGDClassifier(random_state=24)
grid_search = GridSearchCV(sgdc_clf, param_grid, cv=splitter, scoring=f2_scorer)
grid_search.fit(X_ou, y_ou)
# Out:
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1),
#              estimator=SGDClassifier(random_state=24),
#              param_grid={'alpha': array([0.0001, 0.0006]),
#                          'eta0': array([0.01, 0.03, 0.05, 0.07, 0.09, 0.11, 0.13, 0.15, 0.17, 0.19, 0.21,
#        0.23, 0.25, 0.27, 0.29, 0.31, 0.33, 0.35, 0.37, 0.39, 0.41, 0.43,
#        0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65,
#        0.67, 0....
#        1.55, 1.57, 1.59, 1.61, 1.63, 1.65, 1.67, 1.69, 1.71, 1.73, 1.75,
#        1.77, 1.79, 1.81, 1.83, 1.85, 1.87, 1.89, 1.91, 1.93, 1.95, 1.97,
#        1.99]),
#                          'l1_ratio': array([0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
#        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95]),
#                          'learning_rate': ['optimal', 'invscaling', 'adaptive'],
#                          'penalty': ['l2', 'l1', 'elasticnet'],
#                          'random_state': [24]},
#              scoring=make_scorer(fbeta_score, beta=2))

# %%
grid_search.best_estimator_
# Out:
# SGDClassifier(eta0=0.01, l1_ratio=0.05, learning_rate='invscaling',
#               random_state=24)

# %%
cross_val_scores(grid_search.best_estimator_, X_ou, y_ou, splitter)
# Out:
# 0.8003889714657323

# %%
get_val_pred_score(grid_search.best_estimator_, X_ou, y_ou, X_val, y_val)
# Out:
# 0.4057279236276849

# %% [markdown]
# Seems maximising the cross-validation score for train dataset does not improve the validation dataset score.

# %% [markdown]
# AdaBoostClassifier

# %%
param_grid = dict( 
                     base_estimator=[ExtraTreeClassifier(random_state=24)],
                     base_estimator__max_depth=[1, 2, 3],
                     base_estimator__min_samples_leaf=[x for x in range(8, 13)],
                     n_estimators=[x for x in range(800, 1101, 25)],
                     learning_rate=np.arange(0.05, 0.26, 0.05),
                     algorithm=['SAMME.R']
                    )

# %%
ab_clf = AdaBoostClassifier(random_state=24)
grid_search = GridSearchCV(ab_clf, param_grid, cv=splitter, scoring=f2_scorer)
grid_search.fit(X_ou, y_ou)
# Out:
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1),
#              estimator=AdaBoostClassifier(random_state=24),
#              param_grid={'algorithm': ['SAMME.R'],
#                          'base_estimator': [ExtraTreeClassifier(max_depth=3,
#                                                                 min_samples_leaf=8,
#                                                                 random_state=24)],
#                          'base_estimator__max_depth': [1, 2, 3],
#                          'base_estimator__min_samples_leaf': [8, 9, 10, 11, 12],
#                          'learning_rate': array([0.05, 0.1 , 0.15, 0.2 , 0.25]),
#                          'n_estimators': [800, 825, 850, 875, 900, 925, 950,
#                                           975, 1000, 1025, 1050, 1075, 1100]},
#              scoring=make_scorer(fbeta_score, beta=2))

# %%
grid_search.best_estimator_
# Out:
# AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=3,
#                                                       min_samples_leaf=8,
#                                                       random_state=24),
#                    learning_rate=0.25, n_estimators=1100, random_state=24)

# %%
cross_val_scores(grid_search.best_estimator_, X_ou, y_ou, splitter)
# Out:
# 0.8734042619994079

# %%
get_val_pred_score(grid_search.best_estimator_, X_ou, y_ou, X_val, y_val)
# Out:
# 0.26490066225165565

# %% [markdown]
# Seems maximising the cross-validation score for AdaBoostClassifier led to overfitting. The gap between the scores for cross validation and validation dataset prediction is pretty significant.

# %% [markdown]
# OneClassSVM

# %% [markdown]
# GridSearchCV does not work for novelty detection. Let's create simple loops stack to search the hyperparameters.

# %%
param_grid = dict( 
                     kernel=['rbf', 'sigmoid'],
                     gamma=['auto', 'scale'],
                     tol=np.arange(0.1, 3.1, 0.1),
                     nu=np.arange(0.2, 0.61, 0.01)
                    )

# %%
def get_f2_score_for_oc_svm(kernel, gamma, tol, nu):
    oc_svm = OneClassSVM(kernel=kernel, gamma=gamma, tol=tol, nu=nu)
    oc_svm.fit(X_train_out)

    y_pred = oc_svm.predict(X_test_out)

    f2_score = fbeta_score(y_test_out, y_pred, pos_label=-1, beta=2)
    return f2_score

# %%
best_score = 0
best_hp = []
for kernel in param_grid['kernel']:
    for gamma in param_grid['gamma']:
        for tol in param_grid['tol']:
            for nu in param_grid['nu']:
                score = get_f2_score_for_oc_svm(kernel, gamma, tol, round(nu, 2))
                if score > best_score:
                    best_hp = [kernel, gamma, tol, round(nu, 2)]
                    best_score = score

# %%
f'Best score {best_score} has been achieved for {best_hp}'
# Out:
# "Best score 0.3509719222462203 has been achieved for ['rbf', 'scale', 1.5000000000000002, 0.37]"

# %% [raw]
# 0.3510 OneClassSVM(kernel='rbf', gamma='scale', tol=2, nu=0.37)    <-- previous
# 0.3510 OneClassSVM(kernel='rbf', gamma='scale', tol=1.5, nu=0.37)  <-- new

# %%
oc_svm = OneClassSVM(kernel='rbf', gamma='scale', tol=1.5, nu=0.37)
oc_svm.fit(X_train_out)

y_pred = oc_svm.predict(X_test_out)

f2_score = fbeta_score(y_test_out, y_pred, pos_label=-1, beta=2)
f2_score
# Out:
# 0.3509719222462203

# %%
oc_svm = OneClassSVM(kernel='rbf', gamma='scale', tol=1.5, nu=0.37)
oc_svm.fit(X_train_out)

y_pred = oc_svm.predict(X_val_out)

f2_score = fbeta_score(y_val_out, y_pred, pos_label=-1, beta=2)
f2_score
# Out:
# 0.32978723404255317

# %% [markdown]
# The previous and current OneClassSVM give the same result.

# %% [markdown]
# The grid searching have not led to validation dataset improvement.<br>
# <br>
# The hyperameters for these models remain the same:<br>
# 0.4381 SGDClassifier(alpha=0.0004, penalty='elasticnet', l1_ratio=0.05, random_state=24)<br>
# <br>
# 0.4103 AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=2, min_samples_leaf=10, random_state=24),
#                              learning_rate=0.05, n_estimators=900, random_state=24)<br>
# <br>
# 0.3510 OneClassSVM(kernel='rbf', gamma='scale', tol=1.5, nu=0.37)<br>

# %% [markdown]
# The last thing to consider is combining the outlier detection and classification algorithms.<br>
# Firstly, the outliers will be removed from train dataset but only for non-stroke samples. Secondly, the model will be trained on the new dataset (without outliers). Let's see if that will improve the predictions performance.<br>
# Can be done for orginal data and over/under sampled data.<br>

# %% [markdown]
# OneClassSVM + SGDClassifier

# %%
# split stroke and non-stroke samples from train dataset
non_stroke_X_train = X_train[y_train == 0].copy()
non_stroke_y_train = y_train[y_train == 0].copy()
stroke_X_train = X_train[y_train == 1].copy()
stroke_y_train = y_train[y_train == 1].copy()

# for under/oversampled data
# non_stroke_X_train = X_ou[y_ou == 0].copy()
# non_stroke_y_train = y_ou[y_ou == 0].copy()
# stroke_X_train = X_ou[y_ou == 1].copy()
# stroke_y_train = y_ou[y_ou == 1].copy()

# outliers detection in the non-stroke dataset
oc_svm = OneClassSVM(kernel='rbf', gamma='scale', tol=1.5, nu=0.37)
y_od = oc_svm.fit_predict(non_stroke_X_train)

# the predict output is -1 and 1, where 1 means inliers
# so let's keep only these labaled as 1
mask = y_od == 1
non_stroke_X_train, non_stroke_y_train = non_stroke_X_train[mask, :], non_stroke_y_train[mask]

# concat the new non_stroke with stroke datasets
new_X_train = np.concatenate((non_stroke_X_train, stroke_X_train))
new_y_train = np.concatenate((non_stroke_y_train, stroke_y_train))


sgdc = SGDClassifier(alpha=0.0004, penalty='elasticnet', l1_ratio=0.05, random_state=24)

# %%
new_X_train.shape, new_y_train.shape
# Out:
# ((2083, 12), (2083,))

# %%
len(mask[mask == True]), len(mask[mask == False])
# Out:
# (1924, 1187)

# %%
cross_val_scores(sgdc, new_X_train, new_y_train, splitter)
# Out:
# 0.5443090728814661

# %%
get_val_pred_score(sgdc, new_X_train, new_y_train, X_val, y_val)
# Out:
# 0.311284046692607

# %% [markdown]
# OneClassSVM + AdaBoostClassifier

# %% [markdown]
# The data are already prepared so it is just matter of running cross-validation and validation test.

# %%
abc_tng = AdaBoostClassifier(base_estimator=ExtraTreeClassifier(max_depth=2, min_samples_leaf=10, random_state=24),
                             learning_rate=0.05, n_estimators=900, random_state=24)

# %%
cross_val_scores(abc_tng, new_X_train, new_y_train, splitter)
# Out:
# 0.7138814894256138

# %%
get_val_pred_score(abc_tng, new_X_train, new_y_train, X_val, y_val)
# Out:
# 0.39589442815249265

# %% [markdown]
# Combining models do not improve the results for validation dataset. Could be that after additional hyperparameters tuning the results would be better. OneClassSVM labeled 38% of non-stroke samples as the outliers. That shows the dataset is highly varied. It is too many to just ignore them.

# %% [markdown]
# Let's summarise the research in the final notebook the "Stroke_Prediction_Model".
